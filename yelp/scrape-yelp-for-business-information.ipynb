# %%
import pandas as pd
from collections import Counter

import glob # For opening and closing files

# Webpage Stuff
import bs4
from urllib.request import urlopen
import requests
import time
import random
from fake_useragent import UserAgent

import re
import usaddress
import ast # For parsing HTML

# Json stuff
import json
from pandas.io.json import json_normalize
import dask.bag as db

import warnings # Turn off warnings
warnings.filterwarnings('ignore')

# %%
def collect_business_results(page):
    
    # Collect Business Info
    business_info_list = page.findAll("script", {"type": "application/ld+json"})
    busineess_info_script = business_info_list[-1]
    business_info_text = busineess_info_script.get_text().strip().replace("true", "True").replace("false", "False").replace("null", "None")
    business_info_dict = ast.literal_eval(business_info_text)

    # Collect map data
    map_data_text = page.findAll("div", attrs = {"class": "lightbox-map hidden"})[0].get("data-map-state").replace("true", "True").replace("false", "False").replace("null", "None")
    map_data_dict = ast.literal_eval(map_data_text)
    
    # Collect page_count
    if 'reviewCount' in business_info_dict['aggregateRating']:
        review_count = business_info_dict['aggregateRating']['reviewCount']
    else:
        review_count = 0

    # Get whether Business is Open or Not
    biz_closed_list = re.findall('"biz_closed": \[[0-9], \"(True|False)\"\]', page.text)
    if biz_closed_list[0]:
        is_open = 1
    else:
        is_open = 0
        
    # Get attributes
    if page.find("div", {"class": "short-def-list"}):
        attribute_key = page.find("div", {"class": "short-def-list"}).findAll("dt", {"class": "attribute-key"})
        attribute_key_list = list(map(lambda x: x.get_text().strip(), attribute_key))
        attribute_value = page.find("div", {"class": "short-def-list"}).findAll("dd")
        attribute_value_list = list(map(lambda x: x.get_text().strip(), attribute_value))
        attribute_dict = dict(zip(attribute_key_list, attribute_value_list))
    else:
        attribute_dict = None
        
    # Get categories    
    category_str_list = page.find("span", attrs = {"class": "category-str-list"}).findAll('a')
    category_list = list(map(lambda x: x.get_text(), category_str_list))
    category_str = ''
    for i in range(len(category_list)):
        category_str = category_str+category_list[i]+", "
    categories = category_str.strip()[:-1] # Remove ending characters

    # Get hours
    hours_dict = {}
    if page.find("table", {"class": "table table-simple hours-table"}):
        day_table = page.find("table", {"class": "table table-simple hours-table"}).findAll("th")
        hours_table = page.find("table", {"class": "table table-simple hours-table"}).findAll('td')

        for i in range(len(day_table)):
            hours_dict[day_table[i].get_text()] = hours_table[2*i].get_text().strip()
    else:
        hours_dict = None  
    
    data_dict = {'business_id': page.find("div", {"class": "lightbox-map hidden"}).get("data-business-id"),
             'link_id': map_data_dict['markers'][1]['url'].replace('/biz/', ''), # Yes
             'name': business_info_dict['name'],
             'address': business_info_dict['address']['streetAddress'].replace('\n', ' '), # Yes
             'city': business_info_dict['address']['addressLocality'],
             'state': business_info_dict['address']['addressRegion'],
             'postal_code': business_info_dict['address']['postalCode'],
             'telephone': business_info_dict['telephone'],
             'latitude': map_data_dict['markers'][1]['location']['latitude'],
             'longitude': map_data_dict['markers'][1]['location']['longitude'],
             'stars': business_info_dict['aggregateRating']['ratingValue'],
             'review_count': review_count,
             'is_open': is_open,
             'attributes': attribute_dict,
             'categories': categories,
             'hours': hours_dict}
    
    return data_dict

# %%
with open(r'data/url-list.txt') as f: # Grab API Key
    url_list = f.read().splitlines()
    f.close()
    
# Show the first element of the list
ref_dict = dict(zip(range(72), url_list))
ref_dict[0]
# Out:
# 'https://www.yelp.com/biz/aesthetic-climbing-gym-lake-forest'

# %%
data_json = [] # Collect results

# %%
# Monitor the loop in case it breaks.

for url_index in range(27, len(url_list)):

    URL = url_list[url_index]
    
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}
    response  = requests.get(URL, headers = user_agent)
    soup = bs4.BeautifulSoup(response.text)    
    
    # Get number of pages
    page_text = soup.find('div',{"class":"page-of-pages arrange_unit arrange_unit--fill"}).get_text().strip() # Get 'Page <current> of <total>'
    num_pages = int(re.search('(?<=of) [0-9]*', page_text).group(0).strip()) # Get total number of pages
    num_reviews = soup.find('span',{"class":"review-count rating-qualifier"}).get_text().strip() # Get total number of reviews
    business_id = soup.find("div", {"class": "lightbox-map hidden"}).get("data-business-id")
    
    print(*[URL, business_id, 'Index: '+str(url_index), num_reviews], sep="\n") # Quality Control
        
    data_dict = collect_business_results(soup) # Function defined above
    data_json.append(data_dict) # Collect data
    
    time.sleep(10+10*random.random())
    
data_json
# Out:
# https://www.yelp.com/biz/mesa-rim-climbing-and-fitness-center-san-diego-3
# ShWan26H3hBpmvfE9_nTPw
# Index: 27
# 96 reviews
# https://www.yelp.com/biz/mesa-rim-climbing-and-fitness-reno-2
# QiNYgFrT6ySPok_6ePFRqw
# Index: 28
# 26 reviews
# https://www.yelp.com/biz/metalmark-climbing-and-fitness-fresno
# 7n-LZwcoUizVGH5lDgMpVA
# Index: 29
# 41 reviews
# https://www.yelp.com/biz/mission-cliffs-climbing-and-fitness-san-francisco
# yR2AbNAOuzqpJfmGwV0O3g
# Index: 30
# 475 reviews
# https://www.yelp.com/biz/outback-climbing-center-san-diego
# PrDF2ycpOHJq1pot0RY1zA
# Index: 31
# 2 reviews
# https://www.yelp.com/biz/pacific-edge-laguna-beach
# pPJLCarPr3kmvnV0OvmZYQ
# Index: 32
# 591 reviews
# https://www.yelp.com/biz/pacific-edge-rock-climbing-gym-santa-cruz
# dLSkedZvkE1xldE5cwvquA
# Index: 33
# 64 reviews
# https://www.yelp.com/biz/planet-granite-belmont-2
# OJ1Pd42-T1oFIm2sqvy_hA
# Index: 34
# 225 reviews
# https://www.yelp.com/biz/planet-granite-portland-portland
# 6hOQqQa5yK9son4ZKUKoFg
# Index: 35
# 66 reviews
# https://www.yelp.com/biz/planet-granite-san-francisco-2
# qk4sGfV2DQQs1Pe0k54-fA
# Index: 36
# 401 reviews
# https://www.yelp.com/biz/planet-granite-sunnyvale-sunnyvale-2
# qg7vZSKmuQStzpIinOczYA
# Index: 37
# 455 reviews
# https://www.yelp.com/biz/rock-city-climbing-center-anaheim
# i_bedMZOzBBQIJjW-mF_3w
# Index: 38
# 191 reviews
# https://www.yelp.com/biz/rock-fitness-wildomar
# Mzb2zyZFFQ1JekYK2kBxCQ
# Index: 39
# 170 reviews
# https://www.yelp.com/biz/rocknasium-davis
# oHUJu2Z6uw3mfSTY_uOpuA
# Index: 40
# 82 reviews
# https://www.yelp.com/biz/rockreation-los-angeles-4
# Ky4_MzwoLcVhBpuWcJsPwA
# Index: 41
# 214 reviews
# https://www.yelp.com/biz/rockreation-sport-climbing-center-costa-mesa-2
# kf8ordnk5kN1Cz5s5R98BA
# Index: 42
# 128 reviews
# https://www.yelp.com/biz/rockzilla-napa
# 2W3pkmKyoqG6ayHFMQ-nww
# Index: 43
# 39 reviews
# https://www.yelp.com/biz/sacramento-pipeworks-sacramento
# 4dniG36pDnqpPXfQGQDhZg
# Index: 44
# 177 reviews
# https://www.yelp.com/biz/santa-barbara-rock-gym-santa-barbara
# i_VY8EEOxZlNnXrESAhmig
# Index: 45
# 53 reviews
# https://www.yelp.com/biz/sender-one-climbing-and-sender-city-santa-ana-6
# AvYIj1Kzey8XAb07dBYX9A
# Index: 46
# 345 reviews
# https://www.yelp.com/biz/sender-one-climbing-lax-los-angeles-2
# 4TlQdpDRKQVR8jF-wwLxNw
# Index: 47
# 125 reviews
# https://www.yelp.com/biz/sender-one-yoga-and-fitness-santa-ana-4
# NUXYTPnWkTsSCs3BMycwxQ
# Index: 48
# 5 reviews
# https://www.yelp.com/biz/shasta-rock-club-redding
# O9wesGb5fts6d391iGTxRA
# Index: 49
# 6 reviews
# https://www.yelp.com/biz/stonehenge-modesto-2
# Ku5vilcEodzsSYoDOz2TjQ
# Index: 50
# 27 reviews
# https://www.yelp.com/biz/terrain-park-climbing-center-chico
# uEKDNhQTkxclbhJjR-a7xA
# Index: 51
# 7 reviews
# https://www.yelp.com/biz/the-boulder-field-sacramento
# hFgexyILpWZAS7cqZJqlCg
# Index: 52
# 14 reviews
# https://www.yelp.com/biz/the-factory-bouldering-orange-2
# 5tkpswspV1_ibBDpNAqXtw
# Index: 53
# 137 reviews
# https://www.yelp.com/biz/the-pad-climbing-san-luis-obispo
# Hn-frca8Mpe31yj1uSlafA
# Index: 54
# 10 reviews
# https://www.yelp.com/biz/the-pad-santa-maria
# 0LjITGZYRPuBDGZokQd72A
# Index: 55
# 10 reviews
# https://www.yelp.com/biz/the-peak-of-fremont-fremont
# yTw59B9_fH110QiEVFizyA
# Index: 56
# 52 reviews
# https://www.yelp.com/biz/the-stronghold-climbing-gym-los-angeles
# 8KZ0f0Do0Iq0tKcl4R3pmQ
# Index: 57
# 175 reviews
# https://www.yelp.com/biz/the-studio-climbing-san-jose
# u1J4Kt6T2PlvzCblr-fnXg
# Index: 58
# 118 reviews
# https://www.yelp.com/biz/the-wall-climbing-gym-vista-3
# XQp7oU5yYnRFPTWGmlx8IA
# Index: 59
# 57 reviews
# https://www.yelp.com/biz/top-out-climbing-santa-clarita
# GibVU4INC2Y9DuNk7_mOdg
# Index: 60
# 124 reviews
# https://www.yelp.com/biz/verdigo-boulders-burbank
# qSsjmHbBK1eJZm2Z5DmTRQ
# Index: 61
# 16 reviews
# https://www.yelp.com/biz/vertex-climbing-center-santa-rosa
# -t2QKod63eW3cUPpjEgsrQ
# Index: 62
# 46 reviews
# https://www.yelp.com/biz/vertical-hold-rock-climbing-gym-poway
# aMoKeCMN-fauvWA8obVa1A
# Index: 63
# 25 reviews
# https://www.yelp.com/biz/vertical-hold-rock-climbing-gym-san-diego
# eN5TCnsjeynW773GkWSU_g
# Index: 64
# 182 reviews
# https://www.yelp.com/biz/vertical-hold-rock-climbing-gym-san-diego-2
# kABG4yANouUv_WZYQW4weg
# Index: 65
# 182 reviews
# https://www.yelp.com/biz/vertical-hold-rock-climbing-gym-san-marcos
# lI024TtsxTm2Et6Vrbl-nA
# Index: 66
# 68 reviews
# https://www.yelp.com/biz/vital-climbing-gym-bellingham
# Dtvkr8jNiByiusDV92HO6Q
# Index: 67
# 25 reviews
# https://www.yelp.com/biz/vital-climbing-gym-carlsbad
# GGNNSI1vc0pHOppe91gzLQ
# Index: 68
# 58 reviews
# https://www.yelp.com/biz/vital-climbing-gym-murrieta
# DA91L5ZyppOG7-l4wQOSVw
# Index: 69
# 40 reviews
# https://www.yelp.com/biz/vital-climbing-gym-oceanside
# kNS9YGquy0KwL_KAmVuPpQ
# Index: 70
# 73 reviews
# [{'business_id': '3J-Q42JoMUPqRHfUckA2bw',
#   'link_id': 'aesthetic-climbing-gym-lake-forest',
#   'name': 'Aesthetic Climbing Gym',
#   'address': '26794 Vista Ter',
#   'city': 'Lake Forest',
#   'state': 'CA',
#   'postal_code': '92630',
#   'telephone': '+19497167116',
#   'latitude': 33.6649859,
#   'longitude': -117.663927,
#   'stars': 4.5,
#   'review_count': 66,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Venues & Event Spaces, Gyms',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '12:00 pm - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '12:00 pm - 11:00 pm',
#    'Fri': '12:00 pm - 11:00 pm',
#    'Sat': '10:00 am - 10:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'e8qcVa63akVtgO-FFieb3Q',
#   'link_id': 'berkeley-ironworks-climbing-and-fitness-club-berkeley',
#   'name': 'Berkeley Ironworks Climbing & Fitness Club',
#   'address': '800 Potter St',
#   'city': 'Berkeley',
#   'state': 'CA',
#   'postal_code': '94710',
#   'telephone': '+15109819900',
#   'latitude': 37.8508457,
#   'longitude': -122.2925911,
#   'stars': 4.0,
#   'review_count': 310,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Trainers, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'R_cs-7blb1R56oWLvBtwrQ',
#   'link_id': 'blue-granite-climbing-gym-south-lake-tahoe',
#   'name': 'Blue Granite Climbing Gym',
#   'address': '1259 Emerald Bay Rd',
#   'city': 'South Lake Tahoe',
#   'state': 'CA',
#   'postal_code': '96150',
#   'telephone': '+15306002761',
#   'latitude': 38.9056514,
#   'longitude': -119.9990962,
#   'stars': 5.0,
#   'review_count': 9,
#   'is_open': 1,
#   'attributes': {},
#   'categories': 'Climbing, Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 10:00 pm',
#    'Sun': '9:00 am - 10:00 pm'}},
#  {'business_id': 'PDbuxryXvx3usOLVNMOF0Q',
#   'link_id': 'boulderdash-indoor-rock-climbing-thousand-oaks',
#   'name': 'Boulderdash Indoor Rock Climbing',
#   'address': '880 Hampshire Rd Ste A',
#   'city': 'Thousand Oaks',
#   'state': 'CA',
#   'postal_code': '91361',
#   'telephone': '+18055571300',
#   'latitude': 34.1544358,
#   'longitude': -118.8307986,
#   'stars': 4.0,
#   'review_count': 99,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Summer Camps',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'NFpwj4hwofLrE8KSxghucQ',
#   'link_id': 'boulderdash-sfv-chatsworth-6',
#   'name': 'Boulderdash SFV',
#   'address': '19801 Nordhoff Pl Unit 110',
#   'city': 'Chatsworth',
#   'state': 'CA',
#   'postal_code': '91311',
#   'telephone': '+18187001300',
#   'latitude': 34.2362604,
#   'longitude': -118.5657744,
#   'stars': 4.5,
#   'review_count': 60,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'lmVDhvvk7bwoRf4YwUslVw',
#   'link_id': 'boulderdash-ventura-ventura',
#   'name': 'Boulderdash Ventura',
#   'address': '2879 Seaborg Ave Ste 101',
#   'city': 'Ventura',
#   'state': 'CA',
#   'postal_code': '93003',
#   'telephone': '+18056761300',
#   'latitude': 34.246661,
#   'longitude': -119.2120707,
#   'stars': 4.0,
#   'review_count': 3,
#   'is_open': 1,
#   'attributes': {},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'p6L53V8l3R2PmESjULYyzA',
#   'link_id': 'bridges-rock-gym-el-cerrito',
#   'name': 'Bridges Rock Gym',
#   'address': '5635 San Diego St',
#   'city': 'El Cerrito',
#   'state': 'CA',
#   'postal_code': '94530',
#   'telephone': '+15105255635',
#   'latitude': 37.8998627,
#   'longitude': -122.3073412,
#   'stars': 4.5,
#   'review_count': 254,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'RdxAwYiXLb3PQY4MJCGzXA',
#   'link_id': 'cliffs-of-id-culver-city',
#   'name': 'Cliffs of Id',
#   'address': '2537 S Fairfax Ave',
#   'city': 'Culver City',
#   'state': 'CA',
#   'postal_code': '90232',
#   'telephone': '+14245433820',
#   'latitude': 34.0332668,
#   'longitude': -118.3710029,
#   'stars': 4.5,
#   'review_count': 114,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Garage, Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Gyms, Yoga',
#   'hours': {'Mon': '6:30 am - 10:00 pm',
#    'Tue': '6:30 am - 11:00 pm',
#    'Wed': '6:30 am - 10:00 pm',
#    'Thu': '6:30 am - 11:00 pm',
#    'Fri': '6:30 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'cQOMU7by5pdsElUiGEapPQ',
#   'link_id': 'crux-climbing-center-san-luis-obispo',
#   'name': 'Crux Climbing Center',
#   'address': '1160 Laurel Ln',
#   'city': 'San Luis Obispo',
#   'state': 'CA',
#   'postal_code': '93401',
#   'telephone': '+18055442789',
#   'latitude': 35.2640497,
#   'longitude': -120.6435832,
#   'stars': 2.0,
#   'review_count': 77,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Good for Kids': 'No'},
#   'categories': 'Gyms, Boot Camps',
#   'hours': {'Mon': '12:00 pm - 9:00 pm',
#    'Tue': '12:00 pm - 6:00 pm',
#    'Wed': '12:00 pm - 6:00 pm',
#    'Thu': '12:00 pm - 6:00 pm',
#    'Fri': '12:00 pm - 9:00 pm',
#    'Sat': '12:00 pm - 5:00 pm',
#    'Sun': '12:00 pm - 5:00 pm'}},
#  {'business_id': 'Bccp_MZWExiVhksE2oLgGg',
#   'link_id': 'desert-rocks-indoor-climbing-gym-north-palm-springs',
#   'name': 'Desert Rocks Indoor Climbing Gym',
#   'address': '19160 McLane St',
#   'city': 'North Palm Springs',
#   'state': 'CA',
#   'postal_code': '92258',
#   'telephone': '+17606711101',
#   'latitude': 33.909043,
#   'longitude': -116.55183,
#   'stars': 5.0,
#   'review_count': 36,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '12:00 pm - 8:00 pm',
#    'Tue': '12:00 pm - 8:00 pm',
#    'Wed': '12:00 pm - 8:00 pm',
#    'Thu': '12:00 pm - 8:00 pm',
#    'Fri': '12:00 pm - 8:00 pm',
#    'Sat': '12:00 pm - 8:00 pm',
#    'Sun': '12:00 pm - 8:00 pm'}},
#  {'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'link_id': 'diablo-rock-gym-concord-3',
#   'name': 'Diablo Rock Gym',
#   'address': '1220 Diamond Way Ste 140',
#   'city': 'Concord',
#   'state': 'CA',
#   'postal_code': '94520',
#   'telephone': '+19256021000',
#   'latitude': 37.9655526,
#   'longitude': -122.0532716,
#   'stars': 4.0,
#   'review_count': 144,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Yoga, Climbing',
#   'hours': {'Mon': '5:30 am - 10:00 pm',
#    'Tue': '5:30 am - 10:00 pm',
#    'Wed': '5:30 am - 10:00 pm',
#    'Thu': '5:30 am - 10:00 pm',
#    'Fri': '5:30 am - 10:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'ecoN_Wu43bsU3MZbJRZEhg',
#   'link_id': 'dogpatch-boulders-san-francisco',
#   'name': 'Dogpatch Boulders',
#   'address': '2573 3rd St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94107',
#   'telephone': '+14158008121',
#   'latitude': 37.7567228,
#   'longitude': -122.387782,
#   'stars': 4.5,
#   'review_count': 132,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '6:30 am - 11:00 pm',
#    'Tue': '6:30 am - 11:00 pm',
#    'Wed': '6:30 am - 11:00 pm',
#    'Thu': '6:30 am - 11:00 pm',
#    'Fri': '6:30 am - 10:00 pm',
#    'Sat': '10:00 am - 7:00 pm',
#    'Sun': '10:00 am - 7:00 pm'}},
#  {'business_id': 'ycO-JTtTUmVlICz5e0QZfg',
#   'link_id': 'far-north-climbing-arcata',
#   'name': 'Far North Climbing',
#   'address': '1065 K St Ste C',
#   'city': 'Arcata',
#   'state': 'CA',
#   'postal_code': '95521',
#   'telephone': '+17078269558',
#   'latitude': 40.8709869,
#   'longitude': -124.0897937,
#   'stars': 4.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 9:00 pm',
#    'Tue': '9:00 am - 9:00 pm',
#    'Wed': '9:00 am - 9:00 pm',
#    'Thu': '9:00 am - 9:00 pm',
#    'Fri': '9:00 am - 9:00 pm',
#    'Sat': '1:00 pm - 9:00 pm',
#    'Sun': '12:00 pm - 8:00 pm'}},
#  {'business_id': 'sXWXJ6ea8k72_noUbWfW7g',
#   'link_id': 'gold-crush-grass-valley',
#   'name': 'Gold Crush',
#   'address': '124 Clydesdale Ct Ste D',
#   'city': 'Grass Valley',
#   'state': 'CA',
#   'postal_code': '95945',
#   'telephone': '',
#   'latitude': 39.2219493,
#   'longitude': -121.0318079,
#   'stars': 4.0,
#   'review_count': 1,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': 'Closed',
#    'Tue': 'Closed',
#    'Wed': '5:00 am - 10:00 pm',
#    'Thu': '5:00 am - 10:00 pm',
#    'Fri': '5:00 am - 10:00 pm',
#    'Sat': '1:00 pm - 6:00 pm',
#    'Sun': '1:00 pm - 6:00 pm'}},
#  {'business_id': 'L2QBytHClqaRe3oLzCbyjA',
#   'link_id': 'granite-arch-climbing-center-rancho-cordova',
#   'name': 'Granite Arch Climbing Center',
#   'address': '11335 Folsom Blvd Ste G',
#   'city': 'Rancho Cordova',
#   'state': 'CA',
#   'postal_code': '95742',
#   'telephone': '+19168527625',
#   'latitude': 38.6123532,
#   'longitude': -121.2592835,
#   'stars': 4.5,
#   'review_count': 67,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '11:30 am - 10:00 pm',
#    'Tue': '11:30 am - 10:00 pm',
#    'Wed': '11:30 am - 10:00 pm',
#    'Thu': '11:30 am - 10:00 pm',
#    'Fri': '11:30 am - 10:00 pm',
#    'Sat': '11:00 am - 9:30 pm',
#    'Sun': '12:00 pm - 5:00 pm'}},
#  {'business_id': 'NNloS0Q6nDRX4V4x0MaC6g',
#   'link_id': 'great-western-power-company-oakland',
#   'name': 'Great Western Power Company',
#   'address': '520 20th St',
#   'city': 'Oakland',
#   'state': 'CA',
#   'postal_code': '94620',
#   'telephone': '+15104522022',
#   'latitude': 37.8097783,
#   'longitude': -122.2701707,
#   'stars': 4.0,
#   'review_count': 153,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Climbing, Trainers',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'YPWvUVKWwKXd0o1xIBArfg',
#   'link_id': 'grotto-climbing-and-yoga-san-diego',
#   'name': 'Grotto Climbing & Yoga',
#   'address': '4460 Alvarado Canyon Rd',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92120',
#   'telephone': '+16192832105',
#   'latitude': 32.7802694,
#   'longitude': -117.0980249,
#   'stars': 4.5,
#   'review_count': 87,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Yoga, Rock Climbing',
#   'hours': {'Mon': '7:00 am - 12:00 am',
#    'Tue': '6:00 am - 12:00 am',
#    'Wed': '7:00 am - 12:00 am',
#    'Thu': '6:00 am - 12:00 am',
#    'Fri': '7:00 am - 12:00 am',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'i6mMCSWxbbm_b94-Lc_atg',
#   'link_id': 'hangar-18-arcadia-arcadia',
#   'name': 'Hangar 18 - Arcadia',
#   'address': '305 N Santa Anita Ave',
#   'city': 'Arcadia',
#   'state': 'CA',
#   'postal_code': '91006',
#   'telephone': '+16265384081',
#   'latitude': 34.1432717,
#   'longitude': -118.0319401,
#   'stars': 4.0,
#   'review_count': 29,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'oA7eah_MaCQ4PX7XI-IBBg',
#   'link_id': 'hangar-18-east-riverside-riverside',
#   'name': 'Hangar 18 - East Riverside',
#   'address': '2111 Iowa Ave Unit A',
#   'city': 'Riverside',
#   'state': 'CA',
#   'postal_code': '92507',
#   'telephone': '+19517428479',
#   'latitude': 33.9917202,
#   'longitude': -117.3406286,
#   'stars': 4.0,
#   'review_count': 50,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'MwSipWpc6RHImWWVzncMYA',
#   'link_id': 'hangar-18-hawthorne-hawthorne',
#   'name': 'Hangar 18 - Hawthorne',
#   'address': '4926 W Rosecrans Ave',
#   'city': 'Hawthorne',
#   'state': 'CA',
#   'postal_code': '90250',
#   'telephone': '+13109733388',
#   'latitude': 33.9002157979167,
#   'longitude': -118.364760706255,
#   'stars': 3.5,
#   'review_count': 225,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'NdtseuifGWxPmZWLVmI-fA',
#   'link_id': 'hangar-18-long-beach-signal-hill-2',
#   'name': 'Hangar 18 - Long Beach',
#   'address': '2599 E Willow St',
#   'city': 'Signal Hill',
#   'state': 'CA',
#   'postal_code': '90755',
#   'telephone': '+15629813200',
#   'latitude': 33.8051374,
#   'longitude': -118.1615925,
#   'stars': 3.5,
#   'review_count': 131,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'b5pBOaPx0CeVzwjC7j3SgA',
#   'link_id': 'hangar-18-mission-viejo-mission-viejo',
#   'name': 'Hangar 18 - Mission Viejo',
#   'address': '23812 Vía Fabricante Ste A4',
#   'city': 'Mission Viejo',
#   'state': 'CA',
#   'postal_code': '92691',
#   'telephone': '+19494548043',
#   'latitude': 33.6175379,
#   'longitude': -117.6821866,
#   'stars': 4.0,
#   'review_count': 40,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes',
#    'Open to All': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'lDYE1Y3EboCudfFRL9dLhg',
#   'link_id': 'hangar-18-riverside-riverside-2',
#   'name': 'Hangar 18 - Riverside',
#   'address': '6935 Arlington Ave',
#   'city': 'Riverside',
#   'state': 'CA',
#   'postal_code': '92503',
#   'telephone': '+19513595040',
#   'latitude': 33.9462019,
#   'longitude': -117.4461408,
#   'stars': 4.5,
#   'review_count': 127,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Wi-Fi': 'No'},
#   'categories': 'Rock Climbing, Venues & Event Spaces, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'Ui3hw1N8WKjnuHWAP4F2WQ',
#   'link_id': 'hangar-18-upland-upland',
#   'name': 'Hangar 18 - Upland',
#   'address': '256 Stowell St Ste A',
#   'city': 'Upland',
#   'state': 'CA',
#   'postal_code': '91786',
#   'telephone': '+19099315991',
#   'latitude': 34.0939721,
#   'longitude': -117.6479552,
#   'stars': 4.0,
#   'review_count': 201,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Kids Activities',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'HnmbtjXsjFHlAbQ18Od9wA',
#   'link_id': 'hollywood-boulders-los-angeles',
#   'name': 'Hollywood Boulders',
#   'address': '1107 N Bronson Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90038',
#   'telephone': '+13237471000',
#   'latitude': 34.0911978,
#   'longitude': -118.3181587,
#   'stars': 4.5,
#   'review_count': 58,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 11:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'c_kY-WNaL2OGpDryJQ5aHQ',
#   'link_id': 'la-boulders-los-angeles',
#   'name': 'LA Boulders',
#   'address': '1375 E 6th St Unit 8',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90021',
#   'telephone': '+13234069119',
#   'latitude': 34.0390153677829,
#   'longitude': -118.234507063447,
#   'stars': 4.5,
#   'review_count': 162,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing, Yoga',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'mmoy-s1s3LEmgQOFJ4yc5A',
#   'link_id': 'mesa-rim-climbing-and-fitness-center-san-diego-2',
#   'name': 'Mesa Rim Climbing & Fitness Center',
#   'address': '10110 Mesa Rim Rd Mesa Rim Climbing Center',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92121',
#   'telephone': '+18582014411',
#   'latitude': 32.9023232,
#   'longitude': -117.1776669,
#   'stars': 4.5,
#   'review_count': 260,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Day Camps',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'ShWan26H3hBpmvfE9_nTPw',
#   'link_id': 'mesa-rim-climbing-and-fitness-center-san-diego-3',
#   'name': 'Mesa Rim Climbing & Fitness Center',
#   'address': '405 Camino Del Rio S',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92108',
#   'telephone': '+16199081611',
#   'latitude': 32.759566,
#   'longitude': -117.161313,
#   'stars': 4.0,
#   'review_count': 96,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'QiNYgFrT6ySPok_6ePFRqw',
#   'link_id': 'mesa-rim-climbing-and-fitness-reno-2',
#   'name': 'Mesa Rim Climbing & Fitness',
#   'address': '970 Harvard Way',
#   'city': 'Reno',
#   'state': 'NV',
#   'postal_code': '89502',
#   'telephone': '+17755074255',
#   'latitude': 39.5154485955207,
#   'longitude': -119.785389365607,
#   'stars': 4.5,
#   'review_count': 26,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Yoga, Summer Camps',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '7n-LZwcoUizVGH5lDgMpVA',
#   'link_id': 'metalmark-climbing-and-fitness-fresno',
#   'name': 'MetalMark Climbing & Fitness',
#   'address': '4042 N Cedar Ave',
#   'city': 'Fresno',
#   'state': 'CA',
#   'postal_code': '93726',
#   'telephone': '+15592297900',
#   'latitude': 36.7904447910433,
#   'longitude': -119.751904606819,
#   'stars': 4.5,
#   'review_count': 41,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Climbing, Yoga',
#   'hours': {'Mon': '5:00 am - 10:00 pm',
#    'Tue': '5:00 am - 10:00 pm',
#    'Wed': '5:00 am - 10:00 pm',
#    'Thu': '5:00 am - 10:00 pm',
#    'Fri': '5:00 am - 10:00 pm',
#    'Sat': '8:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'yR2AbNAOuzqpJfmGwV0O3g',
#   'link_id': 'mission-cliffs-climbing-and-fitness-san-francisco',
#   'name': 'Mission Cliffs Climbing & Fitness',
#   'address': '2295 Harrison St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94110',
#   'telephone': '+14155500515',
#   'latitude': 37.7607566,
#   'longitude': -122.4124817,
#   'stars': 4.0,
#   'review_count': 475,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': 'Closed'}},
#  {'business_id': 'PrDF2ycpOHJq1pot0RY1zA',
#   'link_id': 'outback-climbing-center-san-diego',
#   'name': 'Outback Climbing Center',
#   'address': '9500 GIlman Dr',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92093',
#   'telephone': '',
#   'latitude': 32.8806061667229,
#   'longitude': -117.23170068115,
#   'stars': 4.0,
#   'review_count': 2,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Climbing',
#   'hours': None},
#  {'business_id': 'pPJLCarPr3kmvnV0OvmZYQ',
#   'link_id': 'pacific-edge-laguna-beach',
#   'name': 'Pacific Edge',
#   'address': '647 S Coast Hwy',
#   'city': 'Laguna Beach',
#   'state': 'CA',
#   'postal_code': '92651',
#   'telephone': '+19492815709',
#   'latitude': 33.538348,
#   'longitude': -117.780549,
#   'stars': 3.0,
#   'review_count': 591,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Apple Pay': 'No',
#    'Accepts Google Pay': 'Yes',
#    'Accepts Cryptocurrency': 'No',
#    'Wi-Fi': 'Free',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Hotels',
#   'hours': {'Mon': 'Open 24 hours',
#    'Tue': 'Open 24 hours',
#    'Wed': 'Open 24 hours',
#    'Thu': 'Open 24 hours',
#    'Fri': 'Open 24 hours',
#    'Sat': 'Open 24 hours',
#    'Sun': 'Open 24 hours'}},
#  {'business_id': 'dLSkedZvkE1xldE5cwvquA',
#   'link_id': 'pacific-edge-rock-climbing-gym-santa-cruz',
#   'name': 'Pacific Edge Rock Climbing Gym',
#   'address': '104 Bronson St Ste 12',
#   'city': 'Santa Cruz',
#   'state': 'CA',
#   'postal_code': '95062',
#   'telephone': '+18314549254',
#   'latitude': 36.9681413,
#   'longitude': -122.0064443,
#   'stars': 4.0,
#   'review_count': 64,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '3:00 pm - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '8:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '8:00 am - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'OJ1Pd42-T1oFIm2sqvy_hA',
#   'link_id': 'planet-granite-belmont-2',
#   'name': 'Planet Granite',
#   'address': '100 El Camino Real',
#   'city': 'Belmont',
#   'state': 'CA',
#   'postal_code': '94002',
#   'telephone': '+16505913030',
#   'latitude': 37.529047205159,
#   'longitude': -122.287440399426,
#   'stars': 4.0,
#   'review_count': 225,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Yoga, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': '6hOQqQa5yK9son4ZKUKoFg',
#   'link_id': 'planet-granite-portland-portland',
#   'name': 'Planet Granite Portland',
#   'address': '1405 NW 14th Ave',
#   'city': 'Portland',
#   'state': 'OR',
#   'postal_code': '97209',
#   'telephone': '+15034775666',
#   'latitude': 45.5330931,
#   'longitude': -122.6860448,
#   'stars': 4.5,
#   'review_count': 66,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Gyms',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'qk4sGfV2DQQs1Pe0k54-fA',
#   'link_id': 'planet-granite-san-francisco-2',
#   'name': 'Planet Granite',
#   'address': '924 Mason St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94129',
#   'telephone': '+14156923434',
#   'latitude': 37.8042571851818,
#   'longitude': -122.468032836914,
#   'stars': 4.5,
#   'review_count': 401,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'qg7vZSKmuQStzpIinOczYA',
#   'link_id': 'planet-granite-sunnyvale-sunnyvale-2',
#   'name': 'Planet Granite Sunnyvale',
#   'address': '815 Stewart Dr',
#   'city': 'Sunnyvale',
#   'state': 'CA',
#   'postal_code': '94085',
#   'telephone': '+14089919090',
#   'latitude': 37.3844235568427,
#   'longitude': -122.010686255225,
#   'stars': 4.5,
#   'review_count': 455,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Gyms, Yoga',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'i_bedMZOzBBQIJjW-mF_3w',
#   'link_id': 'rock-city-climbing-center-anaheim',
#   'name': 'Rock City Climbing Center',
#   'address': '5100 E La Palma Ave Ste 108',
#   'city': 'Anaheim',
#   'state': 'CA',
#   'postal_code': '92807',
#   'telephone': '+17147774884',
#   'latitude': 33.8583613,
#   'longitude': -117.8063943,
#   'stars': 4.5,
#   'review_count': 191,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'No',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Mzb2zyZFFQ1JekYK2kBxCQ',
#   'link_id': 'rock-fitness-wildomar',
#   'name': 'Rock Fitness',
#   'address': '24305 Prielipp Rd Ste 107',
#   'city': 'Wildomar',
#   'state': 'CA',
#   'postal_code': '92595',
#   'telephone': '+19516771122',
#   'latitude': 33.5892442,
#   'longitude': -117.2361054,
#   'stars': 4.5,
#   'review_count': 170,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Climbing, Gyms, Yoga',
#   'hours': {'Mon': '5:00 am - 11:00 pm',
#    'Tue': '5:00 am - 11:00 pm',
#    'Wed': '5:00 am - 11:00 pm',
#    'Thu': '5:00 am - 11:00 pm',
#    'Fri': '5:00 am - 11:00 pm',
#    'Sat': '7:00 am - 10:00 pm',
#    'Sun': '7:00 am - 10:00 pm'}},
#  {'business_id': 'oHUJu2Z6uw3mfSTY_uOpuA',
#   'link_id': 'rocknasium-davis',
#   'name': 'Rocknasium',
#   'address': '720 Olive Dr Ste S',
#   'city': 'Davis',
#   'state': 'CA',
#   'postal_code': '95616',
#   'telephone': '+15307572902',
#   'latitude': 38.5387915,
#   'longitude': -121.7389008,
#   'stars': 4.5,
#   'review_count': 82,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Summer Camps, Climbing',
#   'hours': {'Mon': '10:00 am - 11:00 pm',
#    'Tue': '10:00 am - 11:00 pm',
#    'Wed': '10:00 am - 11:00 pm',
#    'Thu': '10:00 am - 11:00 pm',
#    'Fri': '10:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Ky4_MzwoLcVhBpuWcJsPwA',
#   'link_id': 'rockreation-los-angeles-4',
#   'name': 'Rockreation',
#   'address': '11866 La Grange Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90025',
#   'telephone': '+13102077199',
#   'latitude': 34.03471,
#   'longitude': -118.45342,
#   'stars': 4.0,
#   'review_count': 214,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Cryptocurrency': 'No',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Team Building Activities, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'kf8ordnk5kN1Cz5s5R98BA',
#   'link_id': 'rockreation-sport-climbing-center-costa-mesa-2',
#   'name': 'Rockreation Sport Climbing Center',
#   'address': '1300 Logan Ave',
#   'city': 'Costa Mesa',
#   'state': 'CA',
#   'postal_code': '92626',
#   'telephone': '+17145567625',
#   'latitude': 33.6789371,
#   'longitude': -117.9115365,
#   'stars': 4.0,
#   'review_count': 128,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Yoga, Trainers',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '2W3pkmKyoqG6ayHFMQ-nww',
#   'link_id': 'rockzilla-napa',
#   'name': 'Rockzilla',
#   'address': '849 Jackson St Ste 5A',
#   'city': 'Napa',
#   'state': 'CA',
#   'postal_code': '94559',
#   'telephone': '+17072551500',
#   'latitude': 38.307227,
#   'longitude': -122.288661,
#   'stars': 4.5,
#   'review_count': 39,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '10:00 am - 9:00 pm',
#    'Tue': '10:00 am - 9:00 pm',
#    'Wed': '10:00 am - 9:00 pm',
#    'Thu': '10:00 am - 9:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '4dniG36pDnqpPXfQGQDhZg',
#   'link_id': 'sacramento-pipeworks-sacramento',
#   'name': 'Sacramento Pipeworks',
#   'address': '116 N 16th St',
#   'city': 'Sacramento',
#   'state': 'CA',
#   'postal_code': '95811',
#   'telephone': '+19163410100',
#   'latitude': 38.5890475,
#   'longitude': -121.4812782,
#   'stars': 4.5,
#   'review_count': 177,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'i_VY8EEOxZlNnXrESAhmig',
#   'link_id': 'santa-barbara-rock-gym-santa-barbara',
#   'name': 'Santa Barbara Rock Gym',
#   'address': '322 State St',
#   'city': 'Santa Barbara',
#   'state': 'CA',
#   'postal_code': '93101',
#   'telephone': '+18057703225',
#   'latitude': 34.415240764123,
#   'longitude': -119.69332863015,
#   'stars': 4.5,
#   'review_count': 53,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'AvYIj1Kzey8XAb07dBYX9A',
#   'link_id': 'sender-one-climbing-and-sender-city-santa-ana-6',
#   'name': 'Sender One Climbing and Sender City',
#   'address': '1441 S Village Way',
#   'city': 'Santa Ana',
#   'state': 'CA',
#   'postal_code': '92705',
#   'telephone': '+17148813456',
#   'latitude': 33.7292921,
#   'longitude': -117.8350886,
#   'stars': 4.5,
#   'review_count': 345,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '4TlQdpDRKQVR8jF-wwLxNw',
#   'link_id': 'sender-one-climbing-lax-los-angeles-2',
#   'name': 'Sender One Climbing, Yoga, Fitness and Sender City',
#   'address': '11220 Hindry Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90045',
#   'telephone': '+12132792000',
#   'latitude': 33.9324714,
#   'longitude': -118.371819,
#   'stars': 4.5,
#   'review_count': 125,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Apple Pay': 'No',
#    'Accepts Google Pay': 'No',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Wi-Fi': 'Free',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Kids Activities, Venues & Event Spaces',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'NUXYTPnWkTsSCs3BMycwxQ',
#   'link_id': 'sender-one-yoga-and-fitness-santa-ana-4',
#   'name': 'Sender One Yoga & Fitness',
#   'address': '1431 Village Way Sender One Climbing',
#   'city': 'Santa Ana',
#   'state': 'CA',
#   'postal_code': '92705',
#   'telephone': '+17148813386',
#   'latitude': 33.7293594,
#   'longitude': -117.8356008,
#   'stars': 5.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Yoga, Aerial Fitness, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'O9wesGb5fts6d391iGTxRA',
#   'link_id': 'shasta-rock-club-redding',
#   'name': 'Shasta Rock Club',
#   'address': '2325 Athens Ave',
#   'city': 'Redding',
#   'state': 'CA',
#   'postal_code': '96003',
#   'telephone': '+15306914505',
#   'latitude': 40.5775963,
#   'longitude': -122.3750077,
#   'stars': 5.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Kids Activities',
#   'hours': {'Mon': '1:00 pm - 9:00 pm',
#    'Tue': '1:00 pm - 9:00 pm',
#    'Wed': '1:00 pm - 9:00 pm',
#    'Thu': '1:00 pm - 9:00 pm',
#    'Fri': '1:00 pm - 9:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Ku5vilcEodzsSYoDOz2TjQ',
#   'link_id': 'stonehenge-modesto-2',
#   'name': 'Stonehenge',
#   'address': '500 9th St Ste L2',
#   'city': 'Modesto',
#   'state': 'CA',
#   'postal_code': '95354',
#   'telephone': '+12095213644',
#   'latitude': 37.6359487,
#   'longitude': -120.995429,
#   'stars': 4.5,
#   'review_count': 27,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '6:00 pm - 10:00 pm',
#    'Tue': '6:00 pm - 10:00 pm',
#    'Wed': '6:00 pm - 10:00 pm',
#    'Thu': '6:00 pm - 10:00 pm',
#    'Fri': '6:00 pm - 10:00 pm',
#    'Sat': '2:00 pm - 8:00 pm',
#    'Sun': '2:00 pm - 6:00 pm'}},
#  {'business_id': 'uEKDNhQTkxclbhJjR-a7xA',
#   'link_id': 'terrain-park-climbing-center-chico',
#   'name': 'Terrain Park Climbing Center',
#   'address': '931 W 5th St',
#   'city': 'Chico',
#   'state': 'CA',
#   'postal_code': '95928',
#   'telephone': '+15308090796',
#   'latitude': 39.7225027,
#   'longitude': -121.8458086,
#   'stars': 4.5,
#   'review_count': 7,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes', 'Wheelchair Accessible': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 9:00 pm',
#    'Tue': '9:00 am - 9:00 pm',
#    'Wed': '9:00 am - 9:00 pm',
#    'Thu': '9:00 am - 9:00 pm',
#    'Fri': '9:00 am - 9:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'hFgexyILpWZAS7cqZJqlCg',
#   'link_id': 'the-boulder-field-sacramento',
#   'name': 'The Boulder Field',
#   'address': '8425 Belvedere Ave Ste 100',
#   'city': 'Sacramento',
#   'state': 'CA',
#   'postal_code': '95826',
#   'telephone': '+19163298994',
#   'latitude': 38.5383279608271,
#   'longitude': -121.39422972298,
#   'stars': 4.5,
#   'review_count': 14,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Gyms',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '5tkpswspV1_ibBDpNAqXtw',
#   'link_id': 'the-factory-bouldering-orange-2',
#   'name': 'The Factory Bouldering',
#   'address': '1547 W Struck Ave Ste A',
#   'city': 'Orange',
#   'state': 'CA',
#   'postal_code': '92867',
#   'telephone': '+17146397625',
#   'latitude': 33.8066282,
#   'longitude': -117.869146,
#   'stars': 5.0,
#   'review_count': 137,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 11:00 pm',
#    'Tue': '9:00 am - 11:00 pm',
#    'Wed': '9:00 am - 11:00 pm',
#    'Thu': '9:00 am - 11:00 pm',
#    'Fri': '9:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 9:00 pm'}},
#  {'business_id': 'Hn-frca8Mpe31yj1uSlafA',
#   'link_id': 'the-pad-climbing-san-luis-obispo',
#   'name': 'The Pad Climbing',
#   'address': '888 Ricardo Ct',
#   'city': 'San Luis Obispo',
#   'state': 'CA',
#   'postal_code': '93401',
#   'telephone': '+18442546287',
#   'latitude': 35.2576805,
#   'longitude': -120.6418756,
#   'stars': 4.5,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes', 'Bike Parking': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '11:00 am - 10:00 pm',
#    'Sun': '11:00 am - 10:00 pm'}},
#  {'business_id': '0LjITGZYRPuBDGZokQd72A',
#   'link_id': 'the-pad-santa-maria',
#   'name': 'The Pad',
#   'address': '2399 A St',
#   'city': 'Santa Maria',
#   'state': 'CA',
#   'postal_code': '93454',
#   'telephone': '+18442546287',
#   'latitude': 34.9172903,
#   'longitude': -120.465376,
#   'stars': 5.0,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes', 'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '5:00 pm - 9:00 pm',
#    'Tue': '5:00 pm - 9:00 pm',
#    'Wed': '5:00 pm - 9:00 pm',
#    'Thu': '5:00 pm - 9:00 pm',
#    'Fri': '5:00 pm - 9:00 pm',
#    'Sat': '5:00 pm - 9:00 pm',
#    'Sun': '5:00 pm - 9:00 pm'}},
#  {'business_id': 'yTw59B9_fH110QiEVFizyA',
#   'link_id': 'the-peak-of-fremont-fremont',
#   'name': 'The Peak of Fremont',
#   'address': '4020 Technology Pl',
#   'city': 'Fremont',
#   'state': 'CA',
#   'postal_code': '94538',
#   'telephone': '+15106512500',
#   'latitude': 37.5105907,
#   'longitude': -121.950955,
#   'stars': 4.5,
#   'review_count': 52,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '11:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '8KZ0f0Do0Iq0tKcl4R3pmQ',
#   'link_id': 'the-stronghold-climbing-gym-los-angeles',
#   'name': 'The Stronghold Climbing Gym',
#   'address': '650 S Ave 21',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90031',
#   'telephone': '+13235057000',
#   'latitude': 34.0638055586325,
#   'longitude': -118.216828157672,
#   'stars': 4.5,
#   'review_count': 175,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'u1J4Kt6T2PlvzCblr-fnXg',
#   'link_id': 'the-studio-climbing-san-jose',
#   'name': 'The Studio Climbing',
#   'address': '396 S 1st St',
#   'city': 'San Jose',
#   'state': 'CA',
#   'postal_code': '95113',
#   'telephone': '+14089984000',
#   'latitude': 37.3303191,
#   'longitude': -121.8857449,
#   'stars': 4.5,
#   'review_count': 118,
#   'is_open': 1,
#   'attributes': {'Parking': 'Garage, Street, Private Lot, Validated',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 11:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'XQp7oU5yYnRFPTWGmlx8IA',
#   'link_id': 'the-wall-climbing-gym-vista-3',
#   'name': 'The Wall Climbing Gym',
#   'address': '1210 Keystone Way Ste C',
#   'city': 'Vista',
#   'state': 'CA',
#   'postal_code': '92081',
#   'telephone': '+17605603424',
#   'latitude': 33.136546,
#   'longitude': -117.230456,
#   'stars': 4.5,
#   'review_count': 57,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Climbing',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '12:00 pm - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '12:00 pm - 11:00 pm',
#    'Fri': '12:00 pm - 11:00 pm',
#    'Sat': '10:00 am - 11:00 pm',
#    'Sun': '10:00 am - 10:00 pm'}},
#  {'business_id': 'GibVU4INC2Y9DuNk7_mOdg',
#   'link_id': 'top-out-climbing-santa-clarita',
#   'name': 'Top Out Climbing',
#   'address': '26332 Ferry Ct',
#   'city': 'Santa Clarita',
#   'state': 'CA',
#   'postal_code': '91350',
#   'telephone': '+16612881813',
#   'latitude': 34.4094302,
#   'longitude': -118.5089758,
#   'stars': 5.0,
#   'review_count': 124,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Cannabis Products': 'No'},
#   'categories': 'Rock Climbing, Yoga',
#   'hours': {'Mon': '10:00 am - 11:00 pm',
#    'Tue': '10:00 am - 11:00 pm',
#    'Wed': '10:00 am - 11:00 pm',
#    'Thu': '10:00 am - 11:00 pm',
#    'Fri': '10:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 7:00 pm'}},
#  {'business_id': 'qSsjmHbBK1eJZm2Z5DmTRQ',
#   'link_id': 'verdigo-boulders-burbank',
#   'name': 'Verdigo Boulders',
#   'address': '266 E Magnolia Blvd',
#   'city': 'Burbank',
#   'state': 'CA',
#   'postal_code': '91502',
#   'telephone': '+18189622377',
#   'latitude': 34.1836665,
#   'longitude': -118.3105994,
#   'stars': 4.0,
#   'review_count': 16,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Gyms',
#   'hours': {'Mon': '7:00 am - 10:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 10:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '-t2QKod63eW3cUPpjEgsrQ',
#   'link_id': 'vertex-climbing-center-santa-rosa',
#   'name': 'Vertex Climbing Center',
#   'address': '3358 Coffey Ln Ste A',
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'postal_code': '95403',
#   'telephone': '+17075731608',
#   'latitude': 38.4722644,
#   'longitude': -122.7431565,
#   'stars': 4.0,
#   'review_count': 46,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Trainers',
#   'hours': {'Mon': '8:00 am - 10:00 pm',
#    'Tue': '8:00 am - 10:00 pm',
#    'Wed': '8:00 am - 10:00 pm',
#    'Thu': '8:00 am - 10:00 pm',
#    'Fri': '8:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'aMoKeCMN-fauvWA8obVa1A',
#   'link_id': 'vertical-hold-rock-climbing-gym-poway',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '13026 Stowe Dr',
#   'city': 'Poway',
#   'state': 'CA',
#   'postal_code': '92064',
#   'telephone': '+18587489011',
#   'latitude': 32.943366,
#   'longitude': -117.0438251,
#   'stars': 4.5,
#   'review_count': 25,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Yoga',
#   'hours': {'Mon': '9:00 am - 10:00 pm',
#    'Tue': '9:00 am - 10:00 pm',
#    'Wed': '9:00 am - 10:00 pm',
#    'Thu': '9:00 am - 10:00 pm',
#    'Fri': '9:00 am - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'eN5TCnsjeynW773GkWSU_g',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-diego',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '9580 Distribution Ave',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92121',
#   'telephone': '+18585867572',
#   'latitude': 32.8804632068607,
#   'longitude': -117.164099506184,
#   'stars': 4.5,
#   'review_count': 182,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Yoga',
#   'hours': None},
#  {'business_id': 'kABG4yANouUv_WZYQW4weg',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-diego-2',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '2074 Hancock St',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92110',
#   'telephone': '+16192991124',
#   'latitude': 32.744953,
#   'longitude': -117.189065,
#   'stars': 4.0,
#   'review_count': 182,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '9:00 am - 11:00 pm',
#    'Tue': '9:00 am - 11:00 pm',
#    'Wed': '9:00 am - 11:00 pm',
#    'Thu': '9:00 am - 11:00 pm',
#    'Fri': '9:00 am - 11:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'lI024TtsxTm2Et6Vrbl-nA',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-marcos',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '992 Rancheros Dr',
#   'city': 'San Marcos',
#   'state': 'CA',
#   'postal_code': '92069',
#   'telephone': '+17604801429',
#   'latitude': 33.1367998,
#   'longitude': -117.1328608,
#   'stars': 4.0,
#   'review_count': 68,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'Dtvkr8jNiByiusDV92HO6Q',
#   'link_id': 'vital-climbing-gym-bellingham',
#   'name': 'Vital Climbing Gym',
#   'address': '1421 N State St',
#   'city': 'Bellingham',
#   'state': 'WA',
#   'postal_code': '98225',
#   'telephone': '+13603996248',
#   'latitude': 48.7503208,
#   'longitude': -122.4749387,
#   'stars': 4.5,
#   'review_count': 25,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'GGNNSI1vc0pHOppe91gzLQ',
#   'link_id': 'vital-climbing-gym-carlsbad',
#   'name': 'Vital Climbing Gym',
#   'address': '6102 Avenida Encinas Ste L',
#   'city': 'Carlsbad',
#   'state': 'CA',
#   'postal_code': '92011',
#   'telephone': '+17606892651',
#   'latitude': 33.1180038452148,
#   'longitude': -117.321578979492,
#   'stars': 5.0,
#   'review_count': 58,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Sports Clubs, Climbing, Rock Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'DA91L5ZyppOG7-l4wQOSVw',
#   'link_id': 'vital-climbing-gym-murrieta',
#   'name': 'Vital Climbing Gym',
#   'address': '29990 Technology Dr Ste 22',
#   'city': 'Murrieta',
#   'state': 'CA',
#   'postal_code': '92563',
#   'telephone': '+19512514814',
#   'latitude': 33.5613704,
#   'longitude': -117.1363102,
#   'stars': 4.5,
#   'review_count': 40,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Recreation Centers, Gyms',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'kNS9YGquy0KwL_KAmVuPpQ',
#   'link_id': 'vital-climbing-gym-oceanside',
#   'name': 'Vital Climbing Gym',
#   'address': '525 S Coast Hwy',
#   'city': 'Oceanside',
#   'state': 'CA',
#   'postal_code': '92054',
#   'telephone': '+17603858209',
#   'latitude': 33.1896659,
#   'longitude': -117.3746175,
#   'stars': 4.5,
#   'review_count': 73,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Rock Climbing, Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}}]

# %%
len(data_json)
# Out:
# 71

# %%
# Save file
filename = "climbing-gym-business"
with open('data/{}.json'.format(filename), 'w') as f:
    for i in range(len(climbing_review_json)):
        json.dump(climbing_review_json[i], f)
        f.write('\n')
print("Complete")
# Out:
# Complete

# %%
# Later for opening
business_full_bag = db.read_text("data/climbing-gym-business.json").map(json.loads) # Loads the json file as a dask bag
business_tuple = business_full_bag.take(10000) # Takes the first 10000 entries of the dask bag and stores as a tuple
len(business_tuple)
# Out:
# 71

# %%
business_tuple
# Out:
# ({'business_id': '3J-Q42JoMUPqRHfUckA2bw',
#   'link_id': 'aesthetic-climbing-gym-lake-forest',
#   'name': 'Aesthetic Climbing Gym',
#   'address': '26794 Vista Ter',
#   'city': 'Lake Forest',
#   'state': 'CA',
#   'postal_code': '92630',
#   'telephone': '+19497167116',
#   'latitude': 33.6649859,
#   'longitude': -117.663927,
#   'stars': 4.5,
#   'review_count': 66,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Venues & Event Spaces, Gyms',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '12:00 pm - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '12:00 pm - 11:00 pm',
#    'Fri': '12:00 pm - 11:00 pm',
#    'Sat': '10:00 am - 10:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'e8qcVa63akVtgO-FFieb3Q',
#   'link_id': 'berkeley-ironworks-climbing-and-fitness-club-berkeley',
#   'name': 'Berkeley Ironworks Climbing & Fitness Club',
#   'address': '800 Potter St',
#   'city': 'Berkeley',
#   'state': 'CA',
#   'postal_code': '94710',
#   'telephone': '+15109819900',
#   'latitude': 37.8508457,
#   'longitude': -122.2925911,
#   'stars': 4.0,
#   'review_count': 310,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Trainers, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'R_cs-7blb1R56oWLvBtwrQ',
#   'link_id': 'blue-granite-climbing-gym-south-lake-tahoe',
#   'name': 'Blue Granite Climbing Gym',
#   'address': '1259 Emerald Bay Rd',
#   'city': 'South Lake Tahoe',
#   'state': 'CA',
#   'postal_code': '96150',
#   'telephone': '+15306002761',
#   'latitude': 38.9056514,
#   'longitude': -119.9990962,
#   'stars': 5.0,
#   'review_count': 9,
#   'is_open': 1,
#   'attributes': {},
#   'categories': 'Climbing, Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 10:00 pm',
#    'Sun': '9:00 am - 10:00 pm'}},
#  {'business_id': 'PDbuxryXvx3usOLVNMOF0Q',
#   'link_id': 'boulderdash-indoor-rock-climbing-thousand-oaks',
#   'name': 'Boulderdash Indoor Rock Climbing',
#   'address': '880 Hampshire Rd Ste A',
#   'city': 'Thousand Oaks',
#   'state': 'CA',
#   'postal_code': '91361',
#   'telephone': '+18055571300',
#   'latitude': 34.1544358,
#   'longitude': -118.8307986,
#   'stars': 4.0,
#   'review_count': 99,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Summer Camps',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'NFpwj4hwofLrE8KSxghucQ',
#   'link_id': 'boulderdash-sfv-chatsworth-6',
#   'name': 'Boulderdash SFV',
#   'address': '19801 Nordhoff Pl Unit 110',
#   'city': 'Chatsworth',
#   'state': 'CA',
#   'postal_code': '91311',
#   'telephone': '+18187001300',
#   'latitude': 34.2362604,
#   'longitude': -118.5657744,
#   'stars': 4.5,
#   'review_count': 60,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'lmVDhvvk7bwoRf4YwUslVw',
#   'link_id': 'boulderdash-ventura-ventura',
#   'name': 'Boulderdash Ventura',
#   'address': '2879 Seaborg Ave Ste 101',
#   'city': 'Ventura',
#   'state': 'CA',
#   'postal_code': '93003',
#   'telephone': '+18056761300',
#   'latitude': 34.246661,
#   'longitude': -119.2120707,
#   'stars': 4.0,
#   'review_count': 3,
#   'is_open': 1,
#   'attributes': {},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'p6L53V8l3R2PmESjULYyzA',
#   'link_id': 'bridges-rock-gym-el-cerrito',
#   'name': 'Bridges Rock Gym',
#   'address': '5635 San Diego St',
#   'city': 'El Cerrito',
#   'state': 'CA',
#   'postal_code': '94530',
#   'telephone': '+15105255635',
#   'latitude': 37.8998627,
#   'longitude': -122.3073412,
#   'stars': 4.5,
#   'review_count': 254,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'RdxAwYiXLb3PQY4MJCGzXA',
#   'link_id': 'cliffs-of-id-culver-city',
#   'name': 'Cliffs of Id',
#   'address': '2537 S Fairfax Ave',
#   'city': 'Culver City',
#   'state': 'CA',
#   'postal_code': '90232',
#   'telephone': '+14245433820',
#   'latitude': 34.0332668,
#   'longitude': -118.3710029,
#   'stars': 4.5,
#   'review_count': 114,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Garage, Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Gyms, Yoga',
#   'hours': {'Mon': '6:30 am - 10:00 pm',
#    'Tue': '6:30 am - 11:00 pm',
#    'Wed': '6:30 am - 10:00 pm',
#    'Thu': '6:30 am - 11:00 pm',
#    'Fri': '6:30 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'cQOMU7by5pdsElUiGEapPQ',
#   'link_id': 'crux-climbing-center-san-luis-obispo',
#   'name': 'Crux Climbing Center',
#   'address': '1160 Laurel Ln',
#   'city': 'San Luis Obispo',
#   'state': 'CA',
#   'postal_code': '93401',
#   'telephone': '+18055442789',
#   'latitude': 35.2640497,
#   'longitude': -120.6435832,
#   'stars': 2.0,
#   'review_count': 77,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Good for Kids': 'No'},
#   'categories': 'Gyms, Boot Camps',
#   'hours': {'Mon': '12:00 pm - 9:00 pm',
#    'Tue': '12:00 pm - 6:00 pm',
#    'Wed': '12:00 pm - 6:00 pm',
#    'Thu': '12:00 pm - 6:00 pm',
#    'Fri': '12:00 pm - 9:00 pm',
#    'Sat': '12:00 pm - 5:00 pm',
#    'Sun': '12:00 pm - 5:00 pm'}},
#  {'business_id': 'Bccp_MZWExiVhksE2oLgGg',
#   'link_id': 'desert-rocks-indoor-climbing-gym-north-palm-springs',
#   'name': 'Desert Rocks Indoor Climbing Gym',
#   'address': '19160 McLane St',
#   'city': 'North Palm Springs',
#   'state': 'CA',
#   'postal_code': '92258',
#   'telephone': '+17606711101',
#   'latitude': 33.909043,
#   'longitude': -116.55183,
#   'stars': 5.0,
#   'review_count': 36,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '12:00 pm - 8:00 pm',
#    'Tue': '12:00 pm - 8:00 pm',
#    'Wed': '12:00 pm - 8:00 pm',
#    'Thu': '12:00 pm - 8:00 pm',
#    'Fri': '12:00 pm - 8:00 pm',
#    'Sat': '12:00 pm - 8:00 pm',
#    'Sun': '12:00 pm - 8:00 pm'}},
#  {'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'link_id': 'diablo-rock-gym-concord-3',
#   'name': 'Diablo Rock Gym',
#   'address': '1220 Diamond Way Ste 140',
#   'city': 'Concord',
#   'state': 'CA',
#   'postal_code': '94520',
#   'telephone': '+19256021000',
#   'latitude': 37.9655526,
#   'longitude': -122.0532716,
#   'stars': 4.0,
#   'review_count': 144,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Yoga, Climbing',
#   'hours': {'Mon': '5:30 am - 10:00 pm',
#    'Tue': '5:30 am - 10:00 pm',
#    'Wed': '5:30 am - 10:00 pm',
#    'Thu': '5:30 am - 10:00 pm',
#    'Fri': '5:30 am - 10:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'ecoN_Wu43bsU3MZbJRZEhg',
#   'link_id': 'dogpatch-boulders-san-francisco',
#   'name': 'Dogpatch Boulders',
#   'address': '2573 3rd St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94107',
#   'telephone': '+14158008121',
#   'latitude': 37.7567228,
#   'longitude': -122.387782,
#   'stars': 4.5,
#   'review_count': 132,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '6:30 am - 11:00 pm',
#    'Tue': '6:30 am - 11:00 pm',
#    'Wed': '6:30 am - 11:00 pm',
#    'Thu': '6:30 am - 11:00 pm',
#    'Fri': '6:30 am - 10:00 pm',
#    'Sat': '10:00 am - 7:00 pm',
#    'Sun': '10:00 am - 7:00 pm'}},
#  {'business_id': 'ycO-JTtTUmVlICz5e0QZfg',
#   'link_id': 'far-north-climbing-arcata',
#   'name': 'Far North Climbing',
#   'address': '1065 K St Ste C',
#   'city': 'Arcata',
#   'state': 'CA',
#   'postal_code': '95521',
#   'telephone': '+17078269558',
#   'latitude': 40.8709869,
#   'longitude': -124.0897937,
#   'stars': 4.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 9:00 pm',
#    'Tue': '9:00 am - 9:00 pm',
#    'Wed': '9:00 am - 9:00 pm',
#    'Thu': '9:00 am - 9:00 pm',
#    'Fri': '9:00 am - 9:00 pm',
#    'Sat': '1:00 pm - 9:00 pm',
#    'Sun': '12:00 pm - 8:00 pm'}},
#  {'business_id': 'sXWXJ6ea8k72_noUbWfW7g',
#   'link_id': 'gold-crush-grass-valley',
#   'name': 'Gold Crush',
#   'address': '124 Clydesdale Ct Ste D',
#   'city': 'Grass Valley',
#   'state': 'CA',
#   'postal_code': '95945',
#   'telephone': '',
#   'latitude': 39.2219493,
#   'longitude': -121.0318079,
#   'stars': 4.0,
#   'review_count': 1,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': 'Closed',
#    'Tue': 'Closed',
#    'Wed': '5:00 am - 10:00 pm',
#    'Thu': '5:00 am - 10:00 pm',
#    'Fri': '5:00 am - 10:00 pm',
#    'Sat': '1:00 pm - 6:00 pm',
#    'Sun': '1:00 pm - 6:00 pm'}},
#  {'business_id': 'L2QBytHClqaRe3oLzCbyjA',
#   'link_id': 'granite-arch-climbing-center-rancho-cordova',
#   'name': 'Granite Arch Climbing Center',
#   'address': '11335 Folsom Blvd Ste G',
#   'city': 'Rancho Cordova',
#   'state': 'CA',
#   'postal_code': '95742',
#   'telephone': '+19168527625',
#   'latitude': 38.6123532,
#   'longitude': -121.2592835,
#   'stars': 4.5,
#   'review_count': 67,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '11:30 am - 10:00 pm',
#    'Tue': '11:30 am - 10:00 pm',
#    'Wed': '11:30 am - 10:00 pm',
#    'Thu': '11:30 am - 10:00 pm',
#    'Fri': '11:30 am - 10:00 pm',
#    'Sat': '11:00 am - 9:30 pm',
#    'Sun': '12:00 pm - 5:00 pm'}},
#  {'business_id': 'NNloS0Q6nDRX4V4x0MaC6g',
#   'link_id': 'great-western-power-company-oakland',
#   'name': 'Great Western Power Company',
#   'address': '520 20th St',
#   'city': 'Oakland',
#   'state': 'CA',
#   'postal_code': '94620',
#   'telephone': '+15104522022',
#   'latitude': 37.8097783,
#   'longitude': -122.2701707,
#   'stars': 4.0,
#   'review_count': 153,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Climbing, Trainers',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 7:00 pm',
#    'Sun': '9:00 am - 7:00 pm'}},
#  {'business_id': 'YPWvUVKWwKXd0o1xIBArfg',
#   'link_id': 'grotto-climbing-and-yoga-san-diego',
#   'name': 'Grotto Climbing & Yoga',
#   'address': '4460 Alvarado Canyon Rd',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92120',
#   'telephone': '+16192832105',
#   'latitude': 32.7802694,
#   'longitude': -117.0980249,
#   'stars': 4.5,
#   'review_count': 87,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Yoga, Rock Climbing',
#   'hours': {'Mon': '7:00 am - 12:00 am',
#    'Tue': '6:00 am - 12:00 am',
#    'Wed': '7:00 am - 12:00 am',
#    'Thu': '6:00 am - 12:00 am',
#    'Fri': '7:00 am - 12:00 am',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'i6mMCSWxbbm_b94-Lc_atg',
#   'link_id': 'hangar-18-arcadia-arcadia',
#   'name': 'Hangar 18 - Arcadia',
#   'address': '305 N Santa Anita Ave',
#   'city': 'Arcadia',
#   'state': 'CA',
#   'postal_code': '91006',
#   'telephone': '+16265384081',
#   'latitude': 34.1432717,
#   'longitude': -118.0319401,
#   'stars': 4.0,
#   'review_count': 29,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'oA7eah_MaCQ4PX7XI-IBBg',
#   'link_id': 'hangar-18-east-riverside-riverside',
#   'name': 'Hangar 18 - East Riverside',
#   'address': '2111 Iowa Ave Unit A',
#   'city': 'Riverside',
#   'state': 'CA',
#   'postal_code': '92507',
#   'telephone': '+19517428479',
#   'latitude': 33.9917202,
#   'longitude': -117.3406286,
#   'stars': 4.0,
#   'review_count': 50,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'MwSipWpc6RHImWWVzncMYA',
#   'link_id': 'hangar-18-hawthorne-hawthorne',
#   'name': 'Hangar 18 - Hawthorne',
#   'address': '4926 W Rosecrans Ave',
#   'city': 'Hawthorne',
#   'state': 'CA',
#   'postal_code': '90250',
#   'telephone': '+13109733388',
#   'latitude': 33.9002157979167,
#   'longitude': -118.364760706255,
#   'stars': 3.5,
#   'review_count': 225,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'NdtseuifGWxPmZWLVmI-fA',
#   'link_id': 'hangar-18-long-beach-signal-hill-2',
#   'name': 'Hangar 18 - Long Beach',
#   'address': '2599 E Willow St',
#   'city': 'Signal Hill',
#   'state': 'CA',
#   'postal_code': '90755',
#   'telephone': '+15629813200',
#   'latitude': 33.8051374,
#   'longitude': -118.1615925,
#   'stars': 3.5,
#   'review_count': 131,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'b5pBOaPx0CeVzwjC7j3SgA',
#   'link_id': 'hangar-18-mission-viejo-mission-viejo',
#   'name': 'Hangar 18 - Mission Viejo',
#   'address': '23812 Vía Fabricante Ste A4',
#   'city': 'Mission Viejo',
#   'state': 'CA',
#   'postal_code': '92691',
#   'telephone': '+19494548043',
#   'latitude': 33.6175379,
#   'longitude': -117.6821866,
#   'stars': 4.0,
#   'review_count': 40,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes',
#    'Open to All': 'Yes'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'lDYE1Y3EboCudfFRL9dLhg',
#   'link_id': 'hangar-18-riverside-riverside-2',
#   'name': 'Hangar 18 - Riverside',
#   'address': '6935 Arlington Ave',
#   'city': 'Riverside',
#   'state': 'CA',
#   'postal_code': '92503',
#   'telephone': '+19513595040',
#   'latitude': 33.9462019,
#   'longitude': -117.4461408,
#   'stars': 4.5,
#   'review_count': 127,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Wi-Fi': 'No'},
#   'categories': 'Rock Climbing, Venues & Event Spaces, Climbing',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'Ui3hw1N8WKjnuHWAP4F2WQ',
#   'link_id': 'hangar-18-upland-upland',
#   'name': 'Hangar 18 - Upland',
#   'address': '256 Stowell St Ste A',
#   'city': 'Upland',
#   'state': 'CA',
#   'postal_code': '91786',
#   'telephone': '+19099315991',
#   'latitude': 34.0939721,
#   'longitude': -117.6479552,
#   'stars': 4.0,
#   'review_count': 201,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Kids Activities',
#   'hours': {'Mon': '10:00 am - 10:00 pm',
#    'Tue': '10:00 am - 10:00 pm',
#    'Wed': '10:00 am - 10:00 pm',
#    'Thu': '10:00 am - 10:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'HnmbtjXsjFHlAbQ18Od9wA',
#   'link_id': 'hollywood-boulders-los-angeles',
#   'name': 'Hollywood Boulders',
#   'address': '1107 N Bronson Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90038',
#   'telephone': '+13237471000',
#   'latitude': 34.0911978,
#   'longitude': -118.3181587,
#   'stars': 4.5,
#   'review_count': 58,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 11:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'c_kY-WNaL2OGpDryJQ5aHQ',
#   'link_id': 'la-boulders-los-angeles',
#   'name': 'LA Boulders',
#   'address': '1375 E 6th St Unit 8',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90021',
#   'telephone': '+13234069119',
#   'latitude': 34.0390153677829,
#   'longitude': -118.234507063447,
#   'stars': 4.5,
#   'review_count': 162,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Climbing, Yoga',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'mmoy-s1s3LEmgQOFJ4yc5A',
#   'link_id': 'mesa-rim-climbing-and-fitness-center-san-diego-2',
#   'name': 'Mesa Rim Climbing & Fitness Center',
#   'address': '10110 Mesa Rim Rd Mesa Rim Climbing Center',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92121',
#   'telephone': '+18582014411',
#   'latitude': 32.9023232,
#   'longitude': -117.1776669,
#   'stars': 4.5,
#   'review_count': 260,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Day Camps',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'ShWan26H3hBpmvfE9_nTPw',
#   'link_id': 'mesa-rim-climbing-and-fitness-center-san-diego-3',
#   'name': 'Mesa Rim Climbing & Fitness Center',
#   'address': '405 Camino Del Rio S',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92108',
#   'telephone': '+16199081611',
#   'latitude': 32.759566,
#   'longitude': -117.161313,
#   'stars': 4.0,
#   'review_count': 96,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'QiNYgFrT6ySPok_6ePFRqw',
#   'link_id': 'mesa-rim-climbing-and-fitness-reno-2',
#   'name': 'Mesa Rim Climbing & Fitness',
#   'address': '970 Harvard Way',
#   'city': 'Reno',
#   'state': 'NV',
#   'postal_code': '89502',
#   'telephone': '+17755074255',
#   'latitude': 39.5154485955207,
#   'longitude': -119.785389365607,
#   'stars': 4.5,
#   'review_count': 26,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Yoga, Summer Camps',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '7n-LZwcoUizVGH5lDgMpVA',
#   'link_id': 'metalmark-climbing-and-fitness-fresno',
#   'name': 'MetalMark Climbing & Fitness',
#   'address': '4042 N Cedar Ave',
#   'city': 'Fresno',
#   'state': 'CA',
#   'postal_code': '93726',
#   'telephone': '+15592297900',
#   'latitude': 36.7904447910433,
#   'longitude': -119.751904606819,
#   'stars': 4.5,
#   'review_count': 41,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Climbing, Yoga',
#   'hours': {'Mon': '5:00 am - 10:00 pm',
#    'Tue': '5:00 am - 10:00 pm',
#    'Wed': '5:00 am - 10:00 pm',
#    'Thu': '5:00 am - 10:00 pm',
#    'Fri': '5:00 am - 10:00 pm',
#    'Sat': '8:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'yR2AbNAOuzqpJfmGwV0O3g',
#   'link_id': 'mission-cliffs-climbing-and-fitness-san-francisco',
#   'name': 'Mission Cliffs Climbing & Fitness',
#   'address': '2295 Harrison St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94110',
#   'telephone': '+14155500515',
#   'latitude': 37.7607566,
#   'longitude': -122.4124817,
#   'stars': 4.0,
#   'review_count': 475,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': 'Closed'}},
#  {'business_id': 'PrDF2ycpOHJq1pot0RY1zA',
#   'link_id': 'outback-climbing-center-san-diego',
#   'name': 'Outback Climbing Center',
#   'address': '9500 GIlman Dr',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92093',
#   'telephone': '',
#   'latitude': 32.8806061667229,
#   'longitude': -117.23170068115,
#   'stars': 4.0,
#   'review_count': 2,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Climbing',
#   'hours': None},
#  {'business_id': 'pPJLCarPr3kmvnV0OvmZYQ',
#   'link_id': 'pacific-edge-laguna-beach',
#   'name': 'Pacific Edge',
#   'address': '647 S Coast Hwy',
#   'city': 'Laguna Beach',
#   'state': 'CA',
#   'postal_code': '92651',
#   'telephone': '+19492815709',
#   'latitude': 33.538348,
#   'longitude': -117.780549,
#   'stars': 3.0,
#   'review_count': 591,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Apple Pay': 'No',
#    'Accepts Google Pay': 'Yes',
#    'Accepts Cryptocurrency': 'No',
#    'Wi-Fi': 'Free',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Hotels',
#   'hours': {'Mon': 'Open 24 hours',
#    'Tue': 'Open 24 hours',
#    'Wed': 'Open 24 hours',
#    'Thu': 'Open 24 hours',
#    'Fri': 'Open 24 hours',
#    'Sat': 'Open 24 hours',
#    'Sun': 'Open 24 hours'}},
#  {'business_id': 'dLSkedZvkE1xldE5cwvquA',
#   'link_id': 'pacific-edge-rock-climbing-gym-santa-cruz',
#   'name': 'Pacific Edge Rock Climbing Gym',
#   'address': '104 Bronson St Ste 12',
#   'city': 'Santa Cruz',
#   'state': 'CA',
#   'postal_code': '95062',
#   'telephone': '+18314549254',
#   'latitude': 36.9681413,
#   'longitude': -122.0064443,
#   'stars': 4.0,
#   'review_count': 64,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '3:00 pm - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '8:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '8:00 am - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'OJ1Pd42-T1oFIm2sqvy_hA',
#   'link_id': 'planet-granite-belmont-2',
#   'name': 'Planet Granite',
#   'address': '100 El Camino Real',
#   'city': 'Belmont',
#   'state': 'CA',
#   'postal_code': '94002',
#   'telephone': '+16505913030',
#   'latitude': 37.529047205159,
#   'longitude': -122.287440399426,
#   'stars': 4.0,
#   'review_count': 225,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Yoga, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': '6hOQqQa5yK9son4ZKUKoFg',
#   'link_id': 'planet-granite-portland-portland',
#   'name': 'Planet Granite Portland',
#   'address': '1405 NW 14th Ave',
#   'city': 'Portland',
#   'state': 'OR',
#   'postal_code': '97209',
#   'telephone': '+15034775666',
#   'latitude': 45.5330931,
#   'longitude': -122.6860448,
#   'stars': 4.5,
#   'review_count': 66,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Gyms',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'qk4sGfV2DQQs1Pe0k54-fA',
#   'link_id': 'planet-granite-san-francisco-2',
#   'name': 'Planet Granite',
#   'address': '924 Mason St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': '94129',
#   'telephone': '+14156923434',
#   'latitude': 37.8042571851818,
#   'longitude': -122.468032836914,
#   'stars': 4.5,
#   'review_count': 401,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'qg7vZSKmuQStzpIinOczYA',
#   'link_id': 'planet-granite-sunnyvale-sunnyvale-2',
#   'name': 'Planet Granite Sunnyvale',
#   'address': '815 Stewart Dr',
#   'city': 'Sunnyvale',
#   'state': 'CA',
#   'postal_code': '94085',
#   'telephone': '+14089919090',
#   'latitude': 37.3844235568427,
#   'longitude': -122.010686255225,
#   'stars': 4.5,
#   'review_count': 455,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Gyms, Yoga',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 6:00 pm'}},
#  {'business_id': 'i_bedMZOzBBQIJjW-mF_3w',
#   'link_id': 'rock-city-climbing-center-anaheim',
#   'name': 'Rock City Climbing Center',
#   'address': '5100 E La Palma Ave Ste 108',
#   'city': 'Anaheim',
#   'state': 'CA',
#   'postal_code': '92807',
#   'telephone': '+17147774884',
#   'latitude': 33.8583613,
#   'longitude': -117.8063943,
#   'stars': 4.5,
#   'review_count': 191,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'No',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Mzb2zyZFFQ1JekYK2kBxCQ',
#   'link_id': 'rock-fitness-wildomar',
#   'name': 'Rock Fitness',
#   'address': '24305 Prielipp Rd Ste 107',
#   'city': 'Wildomar',
#   'state': 'CA',
#   'postal_code': '92595',
#   'telephone': '+19516771122',
#   'latitude': 33.5892442,
#   'longitude': -117.2361054,
#   'stars': 4.5,
#   'review_count': 170,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Climbing, Gyms, Yoga',
#   'hours': {'Mon': '5:00 am - 11:00 pm',
#    'Tue': '5:00 am - 11:00 pm',
#    'Wed': '5:00 am - 11:00 pm',
#    'Thu': '5:00 am - 11:00 pm',
#    'Fri': '5:00 am - 11:00 pm',
#    'Sat': '7:00 am - 10:00 pm',
#    'Sun': '7:00 am - 10:00 pm'}},
#  {'business_id': 'oHUJu2Z6uw3mfSTY_uOpuA',
#   'link_id': 'rocknasium-davis',
#   'name': 'Rocknasium',
#   'address': '720 Olive Dr Ste S',
#   'city': 'Davis',
#   'state': 'CA',
#   'postal_code': '95616',
#   'telephone': '+15307572902',
#   'latitude': 38.5387915,
#   'longitude': -121.7389008,
#   'stars': 4.5,
#   'review_count': 82,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Summer Camps, Climbing',
#   'hours': {'Mon': '10:00 am - 11:00 pm',
#    'Tue': '10:00 am - 11:00 pm',
#    'Wed': '10:00 am - 11:00 pm',
#    'Thu': '10:00 am - 11:00 pm',
#    'Fri': '10:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Ky4_MzwoLcVhBpuWcJsPwA',
#   'link_id': 'rockreation-los-angeles-4',
#   'name': 'Rockreation',
#   'address': '11866 La Grange Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90025',
#   'telephone': '+13102077199',
#   'latitude': 34.03471,
#   'longitude': -118.45342,
#   'stars': 4.0,
#   'review_count': 214,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Cryptocurrency': 'No',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Team Building Activities, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'kf8ordnk5kN1Cz5s5R98BA',
#   'link_id': 'rockreation-sport-climbing-center-costa-mesa-2',
#   'name': 'Rockreation Sport Climbing Center',
#   'address': '1300 Logan Ave',
#   'city': 'Costa Mesa',
#   'state': 'CA',
#   'postal_code': '92626',
#   'telephone': '+17145567625',
#   'latitude': 33.6789371,
#   'longitude': -117.9115365,
#   'stars': 4.0,
#   'review_count': 128,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Yoga, Trainers',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '2W3pkmKyoqG6ayHFMQ-nww',
#   'link_id': 'rockzilla-napa',
#   'name': 'Rockzilla',
#   'address': '849 Jackson St Ste 5A',
#   'city': 'Napa',
#   'state': 'CA',
#   'postal_code': '94559',
#   'telephone': '+17072551500',
#   'latitude': 38.307227,
#   'longitude': -122.288661,
#   'stars': 4.5,
#   'review_count': 39,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '10:00 am - 9:00 pm',
#    'Tue': '10:00 am - 9:00 pm',
#    'Wed': '10:00 am - 9:00 pm',
#    'Thu': '10:00 am - 9:00 pm',
#    'Fri': '10:00 am - 9:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '4dniG36pDnqpPXfQGQDhZg',
#   'link_id': 'sacramento-pipeworks-sacramento',
#   'name': 'Sacramento Pipeworks',
#   'address': '116 N 16th St',
#   'city': 'Sacramento',
#   'state': 'CA',
#   'postal_code': '95811',
#   'telephone': '+19163410100',
#   'latitude': 38.5890475,
#   'longitude': -121.4812782,
#   'stars': 4.5,
#   'review_count': 177,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 10:00 pm',
#    'Tue': '6:00 am - 10:00 pm',
#    'Wed': '6:00 am - 10:00 pm',
#    'Thu': '6:00 am - 10:00 pm',
#    'Fri': '6:00 am - 10:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'i_VY8EEOxZlNnXrESAhmig',
#   'link_id': 'santa-barbara-rock-gym-santa-barbara',
#   'name': 'Santa Barbara Rock Gym',
#   'address': '322 State St',
#   'city': 'Santa Barbara',
#   'state': 'CA',
#   'postal_code': '93101',
#   'telephone': '+18057703225',
#   'latitude': 34.415240764123,
#   'longitude': -119.69332863015,
#   'stars': 4.5,
#   'review_count': 53,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '10:00 am - 8:00 pm',
#    'Sun': '10:00 am - 8:00 pm'}},
#  {'business_id': 'AvYIj1Kzey8XAb07dBYX9A',
#   'link_id': 'sender-one-climbing-and-sender-city-santa-ana-6',
#   'name': 'Sender One Climbing and Sender City',
#   'address': '1441 S Village Way',
#   'city': 'Santa Ana',
#   'state': 'CA',
#   'postal_code': '92705',
#   'telephone': '+17148813456',
#   'latitude': 33.7292921,
#   'longitude': -117.8350886,
#   'stars': 4.5,
#   'review_count': 345,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Rock Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '4TlQdpDRKQVR8jF-wwLxNw',
#   'link_id': 'sender-one-climbing-lax-los-angeles-2',
#   'name': 'Sender One Climbing, Yoga, Fitness and Sender City',
#   'address': '11220 Hindry Ave',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90045',
#   'telephone': '+12132792000',
#   'latitude': 33.9324714,
#   'longitude': -118.371819,
#   'stars': 4.5,
#   'review_count': 125,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Accepts Apple Pay': 'No',
#    'Accepts Google Pay': 'No',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Wi-Fi': 'Free',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Kids Activities, Venues & Event Spaces',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'NUXYTPnWkTsSCs3BMycwxQ',
#   'link_id': 'sender-one-yoga-and-fitness-santa-ana-4',
#   'name': 'Sender One Yoga & Fitness',
#   'address': '1431 Village Way Sender One Climbing',
#   'city': 'Santa Ana',
#   'state': 'CA',
#   'postal_code': '92705',
#   'telephone': '+17148813386',
#   'latitude': 33.7293594,
#   'longitude': -117.8356008,
#   'stars': 5.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Yoga, Aerial Fitness, Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 10:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': 'O9wesGb5fts6d391iGTxRA',
#   'link_id': 'shasta-rock-club-redding',
#   'name': 'Shasta Rock Club',
#   'address': '2325 Athens Ave',
#   'city': 'Redding',
#   'state': 'CA',
#   'postal_code': '96003',
#   'telephone': '+15306914505',
#   'latitude': 40.5775963,
#   'longitude': -122.3750077,
#   'stars': 5.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Rock Climbing, Kids Activities',
#   'hours': {'Mon': '1:00 pm - 9:00 pm',
#    'Tue': '1:00 pm - 9:00 pm',
#    'Wed': '1:00 pm - 9:00 pm',
#    'Thu': '1:00 pm - 9:00 pm',
#    'Fri': '1:00 pm - 9:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'Ku5vilcEodzsSYoDOz2TjQ',
#   'link_id': 'stonehenge-modesto-2',
#   'name': 'Stonehenge',
#   'address': '500 9th St Ste L2',
#   'city': 'Modesto',
#   'state': 'CA',
#   'postal_code': '95354',
#   'telephone': '+12095213644',
#   'latitude': 37.6359487,
#   'longitude': -120.995429,
#   'stars': 4.5,
#   'review_count': 27,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Rock Climbing',
#   'hours': {'Mon': '6:00 pm - 10:00 pm',
#    'Tue': '6:00 pm - 10:00 pm',
#    'Wed': '6:00 pm - 10:00 pm',
#    'Thu': '6:00 pm - 10:00 pm',
#    'Fri': '6:00 pm - 10:00 pm',
#    'Sat': '2:00 pm - 8:00 pm',
#    'Sun': '2:00 pm - 6:00 pm'}},
#  {'business_id': 'uEKDNhQTkxclbhJjR-a7xA',
#   'link_id': 'terrain-park-climbing-center-chico',
#   'name': 'Terrain Park Climbing Center',
#   'address': '931 W 5th St',
#   'city': 'Chico',
#   'state': 'CA',
#   'postal_code': '95928',
#   'telephone': '+15308090796',
#   'latitude': 39.7225027,
#   'longitude': -121.8458086,
#   'stars': 4.5,
#   'review_count': 7,
#   'is_open': 1,
#   'attributes': {'Bike Parking': 'Yes', 'Wheelchair Accessible': 'Yes'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 9:00 pm',
#    'Tue': '9:00 am - 9:00 pm',
#    'Wed': '9:00 am - 9:00 pm',
#    'Thu': '9:00 am - 9:00 pm',
#    'Fri': '9:00 am - 9:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'hFgexyILpWZAS7cqZJqlCg',
#   'link_id': 'the-boulder-field-sacramento',
#   'name': 'The Boulder Field',
#   'address': '8425 Belvedere Ave Ste 100',
#   'city': 'Sacramento',
#   'state': 'CA',
#   'postal_code': '95826',
#   'telephone': '+19163298994',
#   'latitude': 38.5383279608271,
#   'longitude': -121.39422972298,
#   'stars': 4.5,
#   'review_count': 14,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Cannabis Products': 'No',
#    'Open to All': 'Yes'},
#   'categories': 'Yoga, Rock Climbing, Gyms',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 8:00 pm',
#    'Sun': '8:00 am - 8:00 pm'}},
#  {'business_id': '5tkpswspV1_ibBDpNAqXtw',
#   'link_id': 'the-factory-bouldering-orange-2',
#   'name': 'The Factory Bouldering',
#   'address': '1547 W Struck Ave Ste A',
#   'city': 'Orange',
#   'state': 'CA',
#   'postal_code': '92867',
#   'telephone': '+17146397625',
#   'latitude': 33.8066282,
#   'longitude': -117.869146,
#   'stars': 5.0,
#   'review_count': 137,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing',
#   'hours': {'Mon': '9:00 am - 11:00 pm',
#    'Tue': '9:00 am - 11:00 pm',
#    'Wed': '9:00 am - 11:00 pm',
#    'Thu': '9:00 am - 11:00 pm',
#    'Fri': '9:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 9:00 pm'}},
#  {'business_id': 'Hn-frca8Mpe31yj1uSlafA',
#   'link_id': 'the-pad-climbing-san-luis-obispo',
#   'name': 'The Pad Climbing',
#   'address': '888 Ricardo Ct',
#   'city': 'San Luis Obispo',
#   'state': 'CA',
#   'postal_code': '93401',
#   'telephone': '+18442546287',
#   'latitude': 35.2576805,
#   'longitude': -120.6418756,
#   'stars': 4.5,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes', 'Bike Parking': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '11:00 am - 10:00 pm',
#    'Sun': '11:00 am - 10:00 pm'}},
#  {'business_id': '0LjITGZYRPuBDGZokQd72A',
#   'link_id': 'the-pad-santa-maria',
#   'name': 'The Pad',
#   'address': '2399 A St',
#   'city': 'Santa Maria',
#   'state': 'CA',
#   'postal_code': '93454',
#   'telephone': '+18442546287',
#   'latitude': 34.9172903,
#   'longitude': -120.465376,
#   'stars': 5.0,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes', 'Good for Kids': 'Yes'},
#   'categories': 'Gyms, Rock Climbing, Yoga',
#   'hours': {'Mon': '5:00 pm - 9:00 pm',
#    'Tue': '5:00 pm - 9:00 pm',
#    'Wed': '5:00 pm - 9:00 pm',
#    'Thu': '5:00 pm - 9:00 pm',
#    'Fri': '5:00 pm - 9:00 pm',
#    'Sat': '5:00 pm - 9:00 pm',
#    'Sun': '5:00 pm - 9:00 pm'}},
#  {'business_id': 'yTw59B9_fH110QiEVFizyA',
#   'link_id': 'the-peak-of-fremont-fremont',
#   'name': 'The Peak of Fremont',
#   'address': '4020 Technology Pl',
#   'city': 'Fremont',
#   'state': 'CA',
#   'postal_code': '94538',
#   'telephone': '+15106512500',
#   'latitude': 37.5105907,
#   'longitude': -121.950955,
#   'stars': 4.5,
#   'review_count': 52,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Rock Climbing, Climbing',
#   'hours': {'Mon': '11:00 am - 10:00 pm',
#    'Tue': '11:00 am - 10:00 pm',
#    'Wed': '11:00 am - 10:00 pm',
#    'Thu': '11:00 am - 10:00 pm',
#    'Fri': '11:00 am - 10:00 pm',
#    'Sat': '11:00 am - 8:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '8KZ0f0Do0Iq0tKcl4R3pmQ',
#   'link_id': 'the-stronghold-climbing-gym-los-angeles',
#   'name': 'The Stronghold Climbing Gym',
#   'address': '650 S Ave 21',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'postal_code': '90031',
#   'telephone': '+13235057000',
#   'latitude': 34.0638055586325,
#   'longitude': -118.216828157672,
#   'stars': 4.5,
#   'review_count': 175,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '6:00 am - 11:00 pm',
#    'Tue': '6:00 am - 11:00 pm',
#    'Wed': '6:00 am - 11:00 pm',
#    'Thu': '6:00 am - 11:00 pm',
#    'Fri': '6:00 am - 11:00 pm',
#    'Sat': '8:00 am - 9:00 pm',
#    'Sun': '8:00 am - 9:00 pm'}},
#  {'business_id': 'u1J4Kt6T2PlvzCblr-fnXg',
#   'link_id': 'the-studio-climbing-san-jose',
#   'name': 'The Studio Climbing',
#   'address': '396 S 1st St',
#   'city': 'San Jose',
#   'state': 'CA',
#   'postal_code': '95113',
#   'telephone': '+14089984000',
#   'latitude': 37.3303191,
#   'longitude': -121.8857449,
#   'stars': 4.5,
#   'review_count': 118,
#   'is_open': 1,
#   'attributes': {'Parking': 'Garage, Street, Private Lot, Validated',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '7:00 am - 11:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 11:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 11:00 pm',
#    'Sat': '9:00 am - 6:00 pm',
#    'Sun': '9:00 am - 6:00 pm'}},
#  {'business_id': 'XQp7oU5yYnRFPTWGmlx8IA',
#   'link_id': 'the-wall-climbing-gym-vista-3',
#   'name': 'The Wall Climbing Gym',
#   'address': '1210 Keystone Way Ste C',
#   'city': 'Vista',
#   'state': 'CA',
#   'postal_code': '92081',
#   'telephone': '+17605603424',
#   'latitude': 33.136546,
#   'longitude': -117.230456,
#   'stars': 4.5,
#   'review_count': 57,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes',
#    'Cannabis Products': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Yoga, Climbing',
#   'hours': {'Mon': '12:00 pm - 11:00 pm',
#    'Tue': '12:00 pm - 11:00 pm',
#    'Wed': '12:00 pm - 11:00 pm',
#    'Thu': '12:00 pm - 11:00 pm',
#    'Fri': '12:00 pm - 11:00 pm',
#    'Sat': '10:00 am - 11:00 pm',
#    'Sun': '10:00 am - 10:00 pm'}},
#  {'business_id': 'GibVU4INC2Y9DuNk7_mOdg',
#   'link_id': 'top-out-climbing-santa-clarita',
#   'name': 'Top Out Climbing',
#   'address': '26332 Ferry Ct',
#   'city': 'Santa Clarita',
#   'state': 'CA',
#   'postal_code': '91350',
#   'telephone': '+16612881813',
#   'latitude': 34.4094302,
#   'longitude': -118.5089758,
#   'stars': 5.0,
#   'review_count': 124,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Cannabis Products': 'No'},
#   'categories': 'Rock Climbing, Yoga',
#   'hours': {'Mon': '10:00 am - 11:00 pm',
#    'Tue': '10:00 am - 11:00 pm',
#    'Wed': '10:00 am - 11:00 pm',
#    'Thu': '10:00 am - 11:00 pm',
#    'Fri': '10:00 am - 11:00 pm',
#    'Sat': '10:00 am - 9:00 pm',
#    'Sun': '10:00 am - 7:00 pm'}},
#  {'business_id': 'qSsjmHbBK1eJZm2Z5DmTRQ',
#   'link_id': 'verdigo-boulders-burbank',
#   'name': 'Verdigo Boulders',
#   'address': '266 E Magnolia Blvd',
#   'city': 'Burbank',
#   'state': 'CA',
#   'postal_code': '91502',
#   'telephone': '+18189622377',
#   'latitude': 34.1836665,
#   'longitude': -118.3105994,
#   'stars': 4.0,
#   'review_count': 16,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Climbing, Gyms',
#   'hours': {'Mon': '7:00 am - 10:00 pm',
#    'Tue': '7:00 am - 11:00 pm',
#    'Wed': '7:00 am - 10:00 pm',
#    'Thu': '7:00 am - 11:00 pm',
#    'Fri': '7:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': '-t2QKod63eW3cUPpjEgsrQ',
#   'link_id': 'vertex-climbing-center-santa-rosa',
#   'name': 'Vertex Climbing Center',
#   'address': '3358 Coffey Ln Ste A',
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'postal_code': '95403',
#   'telephone': '+17075731608',
#   'latitude': 38.4722644,
#   'longitude': -122.7431565,
#   'stars': 4.0,
#   'review_count': 46,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Trainers',
#   'hours': {'Mon': '8:00 am - 10:00 pm',
#    'Tue': '8:00 am - 10:00 pm',
#    'Wed': '8:00 am - 10:00 pm',
#    'Thu': '8:00 am - 10:00 pm',
#    'Fri': '8:00 am - 10:00 pm',
#    'Sat': '10:00 am - 6:00 pm',
#    'Sun': '10:00 am - 6:00 pm'}},
#  {'business_id': 'aMoKeCMN-fauvWA8obVa1A',
#   'link_id': 'vertical-hold-rock-climbing-gym-poway',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '13026 Stowe Dr',
#   'city': 'Poway',
#   'state': 'CA',
#   'postal_code': '92064',
#   'telephone': '+18587489011',
#   'latitude': 32.943366,
#   'longitude': -117.0438251,
#   'stars': 4.5,
#   'review_count': 25,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Rock Climbing, Yoga',
#   'hours': {'Mon': '9:00 am - 10:00 pm',
#    'Tue': '9:00 am - 10:00 pm',
#    'Wed': '9:00 am - 10:00 pm',
#    'Thu': '9:00 am - 10:00 pm',
#    'Fri': '9:00 am - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'eN5TCnsjeynW773GkWSU_g',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-diego',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '9580 Distribution Ave',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92121',
#   'telephone': '+18585867572',
#   'latitude': 32.8804632068607,
#   'longitude': -117.164099506184,
#   'stars': 4.5,
#   'review_count': 182,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Rock Climbing, Yoga',
#   'hours': None},
#  {'business_id': 'kABG4yANouUv_WZYQW4weg',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-diego-2',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '2074 Hancock St',
#   'city': 'San Diego',
#   'state': 'CA',
#   'postal_code': '92110',
#   'telephone': '+16192991124',
#   'latitude': 32.744953,
#   'longitude': -117.189065,
#   'stars': 4.0,
#   'review_count': 182,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Yoga, Rock Climbing',
#   'hours': {'Mon': '9:00 am - 11:00 pm',
#    'Tue': '9:00 am - 11:00 pm',
#    'Wed': '9:00 am - 11:00 pm',
#    'Thu': '9:00 am - 11:00 pm',
#    'Fri': '9:00 am - 11:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'lI024TtsxTm2Et6Vrbl-nA',
#   'link_id': 'vertical-hold-rock-climbing-gym-san-marcos',
#   'name': 'Vertical Hold Rock Climbing Gym',
#   'address': '992 Rancheros Dr',
#   'city': 'San Marcos',
#   'state': 'CA',
#   'postal_code': '92069',
#   'telephone': '+17604801429',
#   'latitude': 33.1367998,
#   'longitude': -117.1328608,
#   'stars': 4.0,
#   'review_count': 68,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Offers Military Discount': 'Yes'},
#   'categories': 'Gyms, Rock Climbing',
#   'hours': {'Mon': '12:00 pm - 10:00 pm',
#    'Tue': '12:00 pm - 10:00 pm',
#    'Wed': '12:00 pm - 10:00 pm',
#    'Thu': '12:00 pm - 10:00 pm',
#    'Fri': '12:00 pm - 10:00 pm',
#    'Sat': '9:00 am - 9:00 pm',
#    'Sun': '9:00 am - 9:00 pm'}},
#  {'business_id': 'Dtvkr8jNiByiusDV92HO6Q',
#   'link_id': 'vital-climbing-gym-bellingham',
#   'name': 'Vital Climbing Gym',
#   'address': '1421 N State St',
#   'city': 'Bellingham',
#   'state': 'WA',
#   'postal_code': '98225',
#   'telephone': '+13603996248',
#   'latitude': 48.7503208,
#   'longitude': -122.4749387,
#   'stars': 4.5,
#   'review_count': 25,
#   'is_open': 1,
#   'attributes': {'Parking': 'Street',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'GGNNSI1vc0pHOppe91gzLQ',
#   'link_id': 'vital-climbing-gym-carlsbad',
#   'name': 'Vital Climbing Gym',
#   'address': '6102 Avenida Encinas Ste L',
#   'city': 'Carlsbad',
#   'state': 'CA',
#   'postal_code': '92011',
#   'telephone': '+17606892651',
#   'latitude': 33.1180038452148,
#   'longitude': -117.321578979492,
#   'stars': 5.0,
#   'review_count': 58,
#   'is_open': 1,
#   'attributes': {'Parking': 'Private Lot',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'Yes'},
#   'categories': 'Sports Clubs, Climbing, Rock Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'DA91L5ZyppOG7-l4wQOSVw',
#   'link_id': 'vital-climbing-gym-murrieta',
#   'name': 'Vital Climbing Gym',
#   'address': '29990 Technology Dr Ste 22',
#   'city': 'Murrieta',
#   'state': 'CA',
#   'postal_code': '92563',
#   'telephone': '+19512514814',
#   'latitude': 33.5613704,
#   'longitude': -117.1363102,
#   'stars': 4.5,
#   'review_count': 40,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Bike Parking': 'Yes',
#    'Good for Kids': 'Yes'},
#   'categories': 'Climbing, Recreation Centers, Gyms',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}},
#  {'business_id': 'kNS9YGquy0KwL_KAmVuPpQ',
#   'link_id': 'vital-climbing-gym-oceanside',
#   'name': 'Vital Climbing Gym',
#   'address': '525 S Coast Hwy',
#   'city': 'Oceanside',
#   'state': 'CA',
#   'postal_code': '92054',
#   'telephone': '+17603858209',
#   'latitude': 33.1896659,
#   'longitude': -117.3746175,
#   'stars': 4.5,
#   'review_count': 73,
#   'is_open': 1,
#   'attributes': {'Accepts Credit Cards': 'Yes',
#    'Parking': 'Street, Private Lot',
#    'Bike Parking': 'Yes',
#    'Wheelchair Accessible': 'Yes',
#    'Good for Kids': 'Yes',
#    'Dogs Allowed': 'No'},
#   'categories': 'Gyms, Rock Climbing, Climbing',
#   'hours': {'Mon': '11:00 am - 9:00 pm',
#    'Tue': '11:00 am - 9:00 pm',
#    'Wed': '11:00 am - 9:00 pm',
#    'Thu': '11:00 am - 9:00 pm',
#    'Fri': '11:00 am - 9:00 pm',
#    'Sat': '11:00 am - 9:00 pm',
#    'Sun': '11:00 am - 9:00 pm'}})
