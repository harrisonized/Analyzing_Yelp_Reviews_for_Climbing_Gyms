# %%
import pandas as pd
from collections import Counter

import glob # For opening and closing files

# Webpage Stuff
import bs4
from urllib.request import urlopen
import requests
import re
import time
import random
from fake_useragent import UserAgent

# Json stuff
import json
from pandas.io.json import json_normalize
import dask.bag as db

import warnings # Turn off warnings
warnings.filterwarnings('ignore')

# %%
def get_vote(review):
    
    vote_type = review.findAll("span", {"class": "vote-type"})
    vote_type_list = list(map(lambda x: x.get_text().strip(), vote_type))
    vote_count = review.findAll("span", {"class": "count"})
    vote_count_text = list(map(lambda x: x.get_text(), vote_count))
    vote_count_list = [0 if x == '' else int(x) for x in vote_count_text]
    vote_dict = dict(zip(vote_type_list, vote_count_list))
    
    return vote_dict



def collect_results(review_content):
    """
    For loop that loops through each page and returns a list of tuples
    Uses the vote_dict() function
    """
    data_list = []
    
    for i in range(1, len(review_content)):
        
        vote_dict = get_vote(review_content[i]) # Get useful, funny, and cool attributes
        date = review_content[i].find('span',{"class":"rating-qualifier"}).get_text().replace("\n", "").strip() # Get date
        date_match = re.search('^\d{1,2}\/\d{1,2}\/\d{4}', date) # Use regex to extract text

        data_dict = {'review_id':review_content[i].get("data-review-id"),
                     'user_id': review_content[i].get("data-signup-object").replace("user_id:", ""),
                     'user_name': review_content[i].find('li', {'class': 'user-name'}).get_text().strip(),
                     'business_id': business_id,
                     'stars': int(float(review_content[i].find('div',{"class":"biz-rating biz-rating-large clearfix"}).div.div.get("title").replace(" star rating", ""))),
                     'useful': vote_dict['Useful'],
                     'funny': vote_dict['Funny'],
                     'cool': vote_dict['Cool'],
                     'text': review_content[i].findAll('div',{"class":"review-content"})[0].find('p').get_text(),
                     'date': date_match.group(0)}
        
        data_list.append(data_dict)
    
    return data_list

# %%
# Show which files are completed
filenames_list = glob.glob("Data/Climbing Gym Reviews/*.json") # Grab a list of filenames
finished_files_list = list(map(lambda x: x.replace("Data/Climbing Gym Reviews/", "").replace(".json",""), sorted(filenames_list)))
finished_files_list # Show list
# Out:
# ['aesthetic_climbing_gym_lake_forest',
#  'berkeley_ironworks_climbing_and_fitness_club_berkeley',
#  'blue_granite_climbing_gym_south_lake_tahoe',
#  'boulderdash_indoor_rock_climbing_thousand_oaks',
#  'boulderdash_sfv_chatsworth_6',
#  'boulderdash_ventura_ventura',
#  'bridges_rock_gym_el_cerrito',
#  'cliffs_of_id_culver_city',
#  'crux_climbing_center_san_luis_obispo',
#  'desert_rocks_indoor_climbing_gym_north_palm_springs',
#  'diablo_rock_gym_concord_3',
#  'dogpatch_boulders_san_francisco',
#  'far_north_climbing_arcata',
#  'gold_crush_grass_valley',
#  'granite_arch_climbing_center_rancho_cordova',
#  'great_western_power_company_oakland',
#  'grotto_climbing_and_yoga_san_diego',
#  'hangar_18_arcadia_arcadia',
#  'hangar_18_east_riverside_riverside',
#  'hangar_18_hawthorne_hawthorne',
#  'hangar_18_long_beach_signal_hill_2',
#  'hangar_18_mission_viejo_mission_viejo',
#  'hangar_18_riverside_riverside_2',
#  'hangar_18_upland_upland',
#  'hollywood_boulders_los_angeles',
#  'la_boulders_los_angeles',
#  'mesa_rim_climbing_and_fitness_center_san_diego_2',
#  'mesa_rim_climbing_and_fitness_center_san_diego_3',
#  'mesa_rim_climbing_and_fitness_reno_2',
#  'metalmark_climbing_and_fitness_fresno',
#  'mission_cliffs_climbing_and_fitness_san_francisco',
#  'outback_climbing_center_san_diego',
#  'pacific_edge_laguna_beach',
#  'pacific_edge_rock_climbing_gym_santa_cruz',
#  'planet_granite_belmont_2',
#  'planet_granite_portland_portland',
#  'planet_granite_san_francisco_2',
#  'planet_granite_sunnyvale_sunnyvale_2',
#  'rock_city_climbing_center_anaheim',
#  'rock_fitness_wildomar',
#  'rocknasium_davis',
#  'rockreation_los_angeles_4',
#  'rockreation_sport_climbing_center_costa_mesa_2',
#  'rockzilla_napa',
#  'sacramento_pipeworks_sacramento',
#  'santa_barbara_rock_gym_santa_barbara',
#  'sender_one_climbing_and_sender_city_santa_ana_6',
#  'sender_one_climbing_lax_los_angeles_2',
#  'sender_one_yoga_and_fitness_santa_ana_4',
#  'shasta_rock_club_redding',
#  'stonehenge_modesto_2',
#  'terrain_park_climbing_center_chico',
#  'the_boulder_field_sacramento',
#  'the_factory_bouldering_orange_2',
#  'the_pad_climbing_san_luis_obispo',
#  'the_pad_santa_maria',
#  'the_peak_of_fremont_fremont',
#  'the_stronghold_climbing_gym_los_angeles',
#  'the_studio_climbing_san_jose',
#  'the_wall_climbing_gym_vista_3',
#  'top_out_climbing_santa_clarita',
#  'verdigo_boulders_burbank',
#  'vertex_climbing_center_santa_rosa',
#  'vertical_hold_rock_climbing_gym_poway',
#  'vertical_hold_rock_climbing_gym_san_diego',
#  'vertical_hold_rock_climbing_gym_san_diego_2',
#  'vertical_hold_rock_climbing_gym_san_marcos',
#  'vital_climbing_gym_bellingham',
#  'vital_climbing_gym_carlsbad',
#  'vital_climbing_gym_murrieta',
#  'vital_climbing_gym_oceanside']

# %%
with open(r'/home/harrisonized/Github/Metis_DS_Projects_Backup/Project 4/Data/url_list.txt') as f: # Grab API Key
    url_list = f.read().splitlines()
    f.close()

# %%
# Show the first element of the list
ref_list = dict(zip(range(72), url_list))
ref_list[0]
# Out:
# 'https://www.yelp.com/biz/aesthetic-climbing-gym-lake-forest'

# %%
# Run this code block by itself
# Monitor this so in case you get blocked by Captchas
# If you send more than 900 requests, you'll get the following error

"""
ConnectionError: HTTPSConnectionPool(host='www.yelp.com', port=443):
Max retries exceeded with url: /biz/planet-granite-san-francisco-2?start=260
(Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb9a31254e0>:
Failed to establish a new connection: [Errno -2] Name or service not known',)
"""

# To be safe, do 10 at a time

for url_index in range(5, 6):

    URL = url_list[url_index]
    
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}
    response  = requests.get(URL, headers = user_agent)
    soup = bs4.BeautifulSoup(response.text)    
    
    # Get number of pages
    page_text = soup.find('div',{"class":"page-of-pages arrange_unit arrange_unit--fill"}).get_text().strip() # Get 'Page <current> of <total>'
    num_pages = int(re.search('(?<=of) [0-9]*', page_text).group(0).strip()) # Get total number of pages
    num_reviews = soup.find('span',{"class":"review-count rating-qualifier"}).get_text().strip() # Get total number of reviews
    business_id = soup.find("div", {"class": "lightbox-map hidden"}).get("data-business-id")

    # Generate list of webpages
    start = 20
    end = num_pages*20
    page_list = [URL]
    while (start < end):
        page_list.append(URL + '?start=' + str(start))
        start += 20
    data_json = [] # Collect results
    print(*[URL, business_id, 'Index: '+str(url_index), str(num_pages) + ' pages', num_reviews], sep="\n") # Quality Control
    
    # Grab webpages:
    for page in page_list[0:len(page_list)]:

        time.sleep(10+10*random.random()) # So Yelp doesn't block IP

        # Generate random user to make it seem like the task is distributed across multiple computers
        ua = UserAgent()
        user_agent = {'User-agent': ua.random}
        response  = requests.get(page, headers = user_agent)
        soup = bs4.BeautifulSoup(response.text)

        review_content = soup.findAll('div',{"class":"review--with-sidebar"}) # Get reviews

        # Collect results and add it to the data_json file
        data_list = collect_results(review_content)
        for i in range(len(data_list)):
            data_json.append(data_list[i])

        print("Collected page: ", page_list.index(page)+1)

    print(data_json) # Print final results
    
    print(len(data_json))
    
    # Save final data as actual JSON
    filename = url_list[url_index].replace("https://www.yelp.com/biz/", "").replace("-", "_")
    with open('Climbing Gym Data/{}.json'.format(filename), 'w') as f:
        for j in range(len(data_json)):
            json.dump(data_json[j], f)
            f.write('\n')
    print("Complete")
# Out:
# https://www.yelp.com/biz/boulderdash-ventura-ventura
# lmVDhvvk7bwoRf4YwUslVw
# Index: 5
# 1 pages
# 3 reviews
# Collected page:  1
# [{'review_id': '4VKBNDSZ9gTwdGUq40b9Lg', 'user_id': 'KkiGd_-z0X4xl957qwB2TA', 'user_name': 'Courtney K.', 'business_id': 'lmVDhvvk7bwoRf4YwUslVw', 'stars': 5, 'useful': 2, 'funny': 0, 'cool': 0, 'text': "We had an AMAZING experience today. My four year old daughter wanted to rock climb for the first time, and we went to Boulderdash not knowing what to do or expect but wanting to help her to try something she was interested in. The extremely professional staff accommodated us on the fly. My daughter became afraid once it was time to climb. But Cat took time to quickly and gently build a rapport with my daughter, and ever-patiently worked as her belay to help her make it to the top. My daughter left feeling accomplished and more confident thanks to Cat's positivity and encouragement. The facility (including the bathroom) is extremely clean. Plenty of space, great lighting, and a stimulating array of climb options. While we were there, we saw kids and parents, couples, novices, and advanced climbers. Lots of smiles everywhere. Great, positive atmosphere. Whether you've rock climbed before or not, Boulderdash is a must-visit. We're so glad we did, and can't wait to go back.", 'date': '2/9/2019'}, {'review_id': 'HRLxsPGaz7TzN0EN4Su-eg', 'user_id': 'rmjMSxj4-3SgD8TuFrXMEA', 'user_name': 'Olivia D.', 'business_id': 'lmVDhvvk7bwoRf4YwUslVw', 'stars': 2, 'useful': 1, 'funny': 2, 'cool': 2, 'text': "Was told I didn't pass my belay test because my feet came off the ground when my partner who weighs 160 lbs took a fall (I'm 100 lbs).It is true I wasn't used to their dynamic rope as SBRG uses semi static but I still didn't think I had done anything unsafe or in a way that would warrant not being allowed to belay.Overall I think the staff is nit-picky and condescending and the routes aren't as good as what you'll find in Santa Barbara or SLO.", 'date': '2/17/2019'}, {'review_id': 'b-FQ13Zn3J5tkG2DPHDy-A', 'user_id': 'qm-BSoJroRRaNsy2rMTGZg', 'user_name': 'Greg B.', 'business_id': 'lmVDhvvk7bwoRf4YwUslVw', 'stars': 5, 'useful': 0, 'funny': 0, 'cool': 1, 'text': "Thank you for opening a killer gym for the Ventura climbing community! \xa0 It's been a long wait since you guys announced wanting to open a gym here but was worth the wait! \xa0 Pro route setters and a nice top out boulder too! \xa0 \xa0Lead climbers just remember to bring ur own rope.", 'date': '3/6/2019'}]
# 3

# %%
# Below is code for running manually
# The purpose of this cell is to prevent the notebook from running below this code block
break
# Out:
#   File "<ipython-input-23-0e516dbbe0b3>", line 5
# SyntaxError: 'break' outside loop

# %%
# Partially manual collection

url_index = 3 # Initialize URL, change the url index manually to prevent getting blocked by Captchas
URL = url_list[url_index]
soup = bs4.BeautifulSoup(urlopen(URL))

# Get number of pages
page_text = soup.find('div',{"class":"page-of-pages arrange_unit arrange_unit--fill"}).get_text().strip() # Get 'Page <current> of <total>'
num_pages = int(re.search('(?<=of) [0-9]*', page_text).group(0).strip()) # Get total number of pages
num_reviews = soup.find('span',{"class":"review-count rating-qualifier"}).get_text().strip() # Get total number of reviews
business_id = soup.find("div", {"class": "lightbox-map hidden"}).get("data-business-id")

# Generate list of webpages
start = 20
end = num_pages*20
page_list = [URL]
while (start < end):
    page_list.append(URL + '?start=' + str(start))
    start += 20
    
data_json = [] # Collect results

print(*[URL, business_id, num_pages, num_reviews], sep="\n") # Quality Control
# Out:
# https://www.yelp.com/biz/boulderdash-indoor-rock-climbing-thousand-oaks
# PDbuxryXvx3usOLVNMOF0Q
# 5
# 99 reviews

# %%
# Grab webpages:

for page in page_list[0:len(page_list)]:
    
    time.sleep(10+10*random.random()) # So Yelp doesn't block IP
    
    # Generate random user to make it seem like the task is distributed across multiple computers
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}
    response  = requests.get(page, headers = user_agent)
    soup = bs4.BeautifulSoup(response.text)
    
    review_content = soup.findAll('div',{"class":"review--with-sidebar"}) # Get reviews
    
    # For each review, collect results
    for i in range(1, len(review_content)):
     
        vote_dict = get_vote(review_content[i]) # Get useful, funny, and cool attributes
        date = review_content[1].find('span',{"class":"rating-qualifier"}).get_text().replace("\n", "").strip() # Get date
        date_match = re.search('^\d{1,2}\/\d{1,2}\/\d{4}', date) # Use regex to extract text
        
        data_dict = {'review_id':review_content[i].get("data-review-id"),
                     'user_id': review_content[i].get("data-signup-object").replace("user_id:", ""),
                     'user_name': review_content[i].find('li', {'class': 'user-name'}).get_text().strip(),
                     'business_id': business_id,
                     'stars': int(float(review_content[i].find('div',{"class":"biz-rating biz-rating-large clearfix"}).div.div.get("title").replace(" star rating", ""))),
                     'useful': vote_dict['Useful'],
                     'funny': vote_dict['Funny'],
                     'cool': vote_dict['Cool'],
                     'text': review_content[i].findAll('div',{"class":"review-content"})[0].find('p').get_text(),
                     'date': date_match.group(0)}
        
        data_json.append(data_dict) # Collect results
        
    print("collected: ", page_list.index(page)+1)
    
data_json # Print results

# %%
len(data_json)
# Out:
# 132

# %%
# Change index manually
filename = url_list[url_index].replace("https://www.yelp.com/biz/", "").replace("-", "_")
with open('Climbing Gym Data/{}.json'.format(filename), 'w') as f:
    for j in range(len(data_json)):
        json.dump(data_json[j], f)
        f.write('\n')
print("Complete")
# Out:
# Complete

# %%
# Inspect
review_full_bag = db.read_text("Data/Climbing Gym Reviews/diablo_rock_gym_concord_3.json").map(json.loads) # Loads the json file as a dask bag
review_tuple = review_full_bag.take(10000) # Takes the first 10000 entries of the dask bag and stores as a tuple
len(review_tuple)
# Out:
# 143

# %%
review_tuple
# Out:
# ({'review_id': 'ejMAXZqxwFM85mX1QT5ZYw',
#   'user_id': 'QtW4RvmEts6jIvl6eXX8FA',
#   'user_name': 'Jorge T.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'My wife took me to go rock climbing for the 1st time and we had a blast. \xa0We took the beginner class and they taught us everything we need to get ready to be let lose on the walls. Ended up spend the whole day their until our arms were to tired to continue climbing. Definitely going back soon.',
#   'date': '3/3/2019'},
#  {'review_id': 'tA9muCjhOV2J_1lR5y8pvQ',
#   'user_id': 'Ld0HLICQ0GisBQ-P7YO0lw',
#   'user_name': 'Elizabeth R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 2,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I love the staff here and the rock climbing is great. Prob is the gym is antiquated and poorly stocked. They dont have the most basic equipment most gyms have..Except in the crossfit area, which costs an additional $20 a month on top of the very high member fee. I can understand paying extra for CLASSES but I can't use the unused space for open gym? How asinine when the reg gym isn't properly stocked. At 24 hr fitness i get all the equipment i need AND classes for half the price. Step it up diablo rock. Here's the issue they don't seem to understand. Crossfit hoards most of the equipment. You can't get realllyyy basic things in the regular gym. Like, a medicine ball/sand ball. We're rationed one. I hope you wanted 10lbs! Want a kettle bell? Well you get exactly 5 to choose from, hope you wanted super light or mega heavy! Want dumbells? Sure! We've got these awkward wide plate ones that are rusting from the 70's! Oh wait, did you want dumb bells lighter than 10lbs? Oh well go dig in that dusty old bucket, im sure youll find one random 8 lb and one 5lb. Hell, sometimes I can't even access the rowing machine because guess what? Crossfit takes that too sometimes! It's fine to say that this isn't a 24hr fitness, sure. But I'm constantly having to improvise my workouts here due to lack of equipment and to see the adequate equipment available but not accessible when membership is already $100+/month is completely uncalled for. They need to either properly stock the reg gym or let paying members access the equipment that, lets be real here, our memberships definitely paid for.",
#   'date': '4/27/2019'},
#  {'review_id': 'jYdGr4dLU5N_AYM3HO1Yng',
#   'user_id': 'sHDozyifQXMu_0Xu9vojuQ',
#   'user_name': 'Daniel R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 0,
#   'cool': 2,
#   'text': "DRG is a clean gym with a friendly staff. Keep in mind that it has a very small bouldering area (the smallest of all the Touchstone gyms) and can get quite crowded during peak hours. They also rely on crash mats for climber safety, as opposed to the fat pad flooring that they have at Dogpatch and Ironworks. This can make falling or jumping down a little more hazardous for those used to the other gyms (I know one climber who recently missed the mat when coming down and suffered a slight ankle sprain). If you want to go bouldering, don't be afraid to move the mats around! There are a lot of routes for those looking to top rope.The workout area is pretty spacious and has a pool on site. The weights and machines are a little dated, but often free for those looking to get in a quick workout. Biggest downside is the parking, which can be quite difficult for those coming in the afternoon.",
#   'date': '3/26/2019'},
#  {'review_id': 'ntdu4eMr4Knakgb3TtfYSQ',
#   'user_id': 'tLQraDeMnxDJ-5z0j0Msdg',
#   'user_name': 'Beverly W.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Great place!! CrossFit classes are fun and the instructors know what they're doing. Most affordable CrossFit around - especially considering everything else you get with your membership. Coco's definitely worth the extra $20. Commendable staff and a recherché facility!",
#   'date': '4/26/2019'},
#  {'review_id': 'SKogKLiHq_eb-jz-5zsdmQ',
#   'user_id': 'cuJ3t1EV2YSao6MiM3B1wA',
#   'user_name': 'Evita B.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "Had purchased this community program pass from work to go to this gym. I've done some rock climbing in the past but nothing like what this gym has to offer. Went to use the day pass and expected to be given some kind of tour of the gym, but we got our shoes and were set free to find the bouldering wall. Luckily my boyfriend had been here before so he knew where to go. I haven't really bouldered before but really enjoyed how they write the difficultly level or each route. I'm totally going to come back and give this bouldering thing another try!",
#   'date': '12/10/2018'},
#  {'review_id': 'aSceF45fVTJdVkesLcErpg',
#   'user_id': 'ISYQNaFs3Y9IVWX885KPGQ',
#   'user_name': 'E E M.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Best vibe and management of all the locations I frequent (here, GWPC, and Ironworks). Bouldering area is small, but you can find it empty during off hours. This is hands-down my favorite gym in the Bay. Keep up the good work!',
#   'date': '4/21/2019'},
#  {'review_id': 'wW8OPW2WdAk15Nk_rm0doQ',
#   'user_id': 'eBxUsR4bE-IVcIEvTrrdUw',
#   'user_name': 'Melissa M.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "My new favorite gym! All the staff \xa0are very friendly and informative. Overall the gym was extremely clean. I've never experience a steam room until this gym and they have a dry sauna as well. Definitely feeling great after a good workout and post sweat. Can't wait to bring all my friends.",
#   'date': '12/10/2018'},
#  {'review_id': 'zjlRVyeus4-jMm8BGlzkaw',
#   'user_id': 'OPsI52JQ7YLsyhzC8UwJiA',
#   'user_name': 'James B.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 7,
#   'funny': 0,
#   'cool': 3,
#   'text': "Dropped in for the parenting and kids belay class this Sunday. $35 for the parent + $10 (Kid #1) + $20 (Kid #2). Kids are 5 & 7 and they had a blast. Will be hosting a birthday party here soon.Welcoming and laid back environment. Conveniently located by the freeway with plenty of parking. If it were closer, we'd be regulars. Tips:Bring a snack and a water bottle. No need to buy your own gear. Rental prices are reasonable. Between climbs feel free to drop into the open gym to get some squats or pull ups in.The perfect excuse to cross Willow Pass Road to drop in to some of my favorites: Dos Coyotes, Road Runner, Eureka, and REI.",
#   'date': '8/6/2017'},
#  {'review_id': 'o0iFSD6Lp1yvXS9K1q0O_Q',
#   'user_id': 'IsByGKw_zdOdH9yDLFcGeA',
#   'user_name': 'Yee W.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "We came in to check this place out due to curiosity. The woman who was behind the desk was very informative and helpful. She explained everything to us and we got to walk around to take a look. There's exercises machines, two different climbing walls.. beginner and advance.. bathrooms were clean. The vibe I got from this place was cool. Everyone do their own thang. Discounts for first responders. Not too expensive, you can also go to other gyms as well.We're still not sure, debating on their membership, but I wouldn't mind joining!",
#   'date': '10/11/2018'},
#  {'review_id': 'HEtjbqzCLPSrsz2st21f-Q',
#   'user_id': 'UC0u8rQOI1VjNTcLapXnsw',
#   'user_name': 'Elizabete Maria T.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "We had a great time over here. We came since we couldn't play outside. The staff is friendly, classes are great. Restrooms are clean. They have a 10 foot wall and 30 feet walls. My kid enjoyed the experience. We are cool back in a few.",
#   'date': '11/11/2018'},
#  {'review_id': 'MsZOZ0PsGOkNJvv_Y10Dag',
#   'user_id': 'cAUocrfoPyXcUUfRSGdDkg',
#   'user_name': 'Jessica F.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "Hubs and I finally got to check this place out for a date night. We took the beginners class to belay. It was well explained how to properly tie your rope to climb and well as how to hook up to support your climbing partner. After a practice climb up the wall you get a yellow card to day climb. You can drop in anytime to belay but you have to test to get your card each time. The gym membership itself is too pricy for me but to drop in once in awhile is perfect. Can't wait to come back again.",
#   'date': '10/24/2018'},
#  {'review_id': 'qvXkdsMIw9TTxHZzxD-RtQ',
#   'user_id': 'PiBA8dz-OwdnmodpbwIoPQ',
#   'user_name': 'J. N.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': 'What a great place for kids (and adults)! We had a party here for 6 kids aged 7-9 and the staff was great and I feel the prices are reasonable. \xa0The facility is fantastic, with lots of options - belay, bouldering, slack lines, etc. \xa0This is also a great place to bring kids on a weekend or for a play date. Gets them active, away from screens, video games, etc. and challenges them physically and mentally.',
#   'date': '7/9/2018'},
#  {'review_id': 'qM4_DXcTo2mO_1jmTIUDvw',
#   'user_id': 'SgIGk0iCYFnHzc3lLjbz9Q',
#   'user_name': 'Marcie I.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This place is a gem. It is a great place to go for the whole family. We can all get exercise and everyone is challenged at their own level. The community is supportive and the people who work there are passionate and helpful. This has become a home away from home for our oldest daughter. We can now drop her off for an hour of climbing and she loves it. Highly recommend joining!',
#   'date': '12/31/2018'},
#  {'review_id': 'IdwrShwFbwsk7WW4Rud8Uw',
#   'user_id': 'NjfSkOTtpNzZrQzo8i4Zcg',
#   'user_name': 'Gab R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Such a gem within the Touchstone community, seriously! \xa0DRG certainly has a mom and pop feel, which makes it a stand out in the corporate gym network. \xa0The staff are welcoming and the gym has a great selection of routes, both for bouldering and rope, a slack line, an indo board, campus board, weight room, and a pool (available for day or membership use?).DRG deserves more attention of Touchstone, however. We noticed that many routes have been around for 10+ weeks. \xa0The politics of business are at work here, I am sure, but it seems unfair to have DRG not receive the same attention as Ironworks, Great Western Power and San Jose regarding route setting. \xa0This gym is stellar and is in need of more TLC from its corp. \xa0There is a great community here and I look forward to continue supporting DRG when I look for rope time as Bridges is my home gym.',
#   'date': '11/13/2017'},
#  {'review_id': 'Cpfju2dT09TLDXcQV2pTKw',
#   'user_id': '6X68M-UVJN7m0Ssc1hMtOQ',
#   'user_name': 'Mary G.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Great place to wall climb. Lots of different walls for different levels. They also have a small bouldering area and a small gym as well. Staff were friendly, parking was ok but it was a little difficult to find a spot. The first time you go you have to take a really short course to know the basics, also for safety. It was a little more expensive compared to other wall climbing places but its a one time expense.',
#   'date': '5/8/2017'},
#  {'review_id': 'vgXITaQ2uK28PMET91KuVg',
#   'user_id': '8dpqRMuHRnPwJPzyUp1nwA',
#   'user_name': 'Kristina S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "I really loved this place!! We came here to celebrate my cousin's birthday. What better way to celebrate a birthday than to climb some rocks. Lol. Anyway, parking was no problem, and it's pretty easy to find. We checked in, signed some waivers then took our beginner course with Jonny, since we are all noobs. He was very nice and helpful. Everything made sense and in 30 minutes or so, my group and I were confident to take on the rocks!If you're looking to have some fun and also to challenge yourself (because rock climbing isn't easy), you should check this place out. I'd love to come back.Deducted a star because some of the ropes are a little smelly. I feel like they should clean more often? or replace more often. Just a suggestion for management. Other than that, this place would've been a solid 5 stars.",
#   'date': '3/18/2017'},
#  {'review_id': 'jz7aNggE1rPsxG_RODlXDA',
#   'user_id': '_O8ipVq6qy1sDhD5z7s0Ag',
#   'user_name': 'Angelina D.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 0,
#   'cool': 1,
#   'text': 'I have been a Diablo Rock member for a few years. I like the installations and class offerings. Routes change often to keep things interesting and new. The staff is very friendly and helpful. There is a sense of community that I have not felt in other gyms, even other Touchstone gyms.',
#   'date': '2/6/2018'},
#  {'review_id': 'qe8_fzQRpyFrIlSwg0ZUUg',
#   'user_id': 'KRYQGA74lf-HMqHNayfISQ',
#   'user_name': 'Claudia C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 2,
#   'cool': 3,
#   'text': "Relatively large gym with friendly staff and tons of courses with varying degrees of difficulty.We're not regulars yet, but hope to frequent this gym more going forward. We signed up for the intro to rock climbing class to learn the basics. The first time around I made a scheduling faux pas (got the time wrong and arrived for the class an hour late). The folks working here were super forgiving/understanding and let me reschedule for the following week.During the second attempt (which was a success!), we had a great experience learning the ropes. The instructor was attentive and went at a pace that enabled everyone to follow along. Afterwards, we got to climb as many walls for as long as we wanted.Prices are a little steep (about $20 for a day pass on the weekends), but it's what you'd expect to pay for any single session at a yoga parlor or cycle place.My only qualm is that it kind of smells here, but it's expected with any gym.Other than that, this will most likely become our go-to gym for rock climbing.",
#   'date': '9/21/2016'},
#  {'review_id': '-jNauAYbSviuFlhs7gBQQw',
#   'user_id': 'noPnGMkmbrrkWPc_05e5zQ',
#   'user_name': 'Avigdor G.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 1,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Really not worth going to, poor sanitary conditions, I'd go anywhere else. Unfortunately not a lot of other options",
#   'date': '9/9/2018'},
#  {'review_id': 'CJxIJ6h9JWnyGuWuG35sZg',
#   'user_id': 'Hi0T4tXQWU48EweYwbpWcg',
#   'user_name': 'Anjelica C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I have officially been a member here for a year now. \xa0All of the workers are really laid back and friendly. \xa0I have never felt intimidated and always felt welcome. \xa0Theres a good mix of routes here. \xa0I'm still a beginner so there are still really challenging routes for me. \xa0I can't lead climb, so no opinion there, but I love taking a break and watching the pros go at it. \xa0The gym gets pretty crowded on weekdays and the parking lot is NUTS. \xa0They share a lot with the swim school next door and it can get busy on a week night. \xa0The bouldering area is nice but also gets pretty crowded. \xa0It's smaller compared to some other Touchstone gyms. \xa0They have a slack line set up every once in a while. \xa0The gym equipment is also decent. \xa0My husband and I tried out a swing class. \xa0It unfortunately didn't work out with our schedules, but it was cool they offered it.",
#   'date': '1/19/2017'},
#  {'review_id': 'gVbCW9u3Jsm0rxgW_d05Kg',
#   'user_id': '51Wt6Sqp0HG2zv8tZ_VGeg',
#   'user_name': 'Blaine J.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 1,
#   'cool': 3,
#   'text': "Been coming here for years. You get what you pay for. Has so many activities and I love how down to earth the place is. It does have some downfalls as any business does but to me it's minor. Sometimes it's short staffed or the front desk dude seems high or something but eh. Everyone has always given me what I needed and has always been knowledgeable while helpful even if they're busy and can't get around to everything at once. I recommend visiting when it's not busy for your first experience to not get impatient or overwhelmed. For the price tho it's worth it and it's mainly about having a good time with good people while maintaining a healthy life style. Just chill and don't act like a princess or prince or whatever. You'll be aight.",
#   'date': '3/9/2017'},
#  {'review_id': 'gx9MeUD1q2R-klG-Z2b4qg',
#   'user_id': '8SwvVc04xxk98SlXRfs66A',
#   'user_name': 'Julia L.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "Awesome climbing gym for the kids. I'd love to try myself one day. On weekends they have kids' belay, and one of their staff will expertly work with your child. We've also booked a birthday party here and it's loads of fun. Both Steve and Elizabeth were great with the kids, encouraging and patient. They have a dedicated small party room so you can do food and cake.I had to change the number of our party several times (and even after the fact), and each time the staff member assisting was friendly and helpful.We'll be back for the parents' training class!",
#   'date': '4/21/2017'},
#  {'review_id': 'wlSg2TVdGF9ByDfU9wb8gQ',
#   'user_id': 'B3cOX_VmahpCGvZzyVIEig',
#   'user_name': 'Richard N.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "This place is awesome, so awesome in fact that we decided to join here as our normal gym. The lead climbing routes are challenging, although they aren't too high, but they have a good amount of routes. \xa0The staff here is pretty good about switching it up and updating the routes often. \xa0There's a bouldering section in here as well but is pretty small compared to other places that we've been.The gym area itself is small as well, but they have everything that you need equipment wise. \xa0Diablo Rock also offers a good variety of different classes for its members. \xa0Crossfit is also available for those into that. \xa0To top it off, the staff here is awesome. \xa0They're always friendly and helpful and all appear to love their jobs and this gym!",
#   'date': '1/25/2017'},
#  {'review_id': '2YG1sg3b85NSEf9f6WBh8Q',
#   'user_id': 'g5_MHfgZyY6PQSQqSE2REA',
#   'user_name': 'Kim P.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 1,
#   'cool': 1,
#   'text': "I really liked this place!! It's like a fun playhouse for adults and kids! My sister & I did a class. We were grouped with two others. Our teacher was very patient and knowledgeable. She had us go through the motions a bunch of times until we were comfortable. I really liked how she would show us step by step, we would do the steps together, and then we would do it on our own a few times & she'd check each one of us! The lesson is like 30 minutes and then you get to climb. The teacher watched us and helped us when needed. She watched probably 2-3 climbs and then the class was over. After the class is over, you get a full day pass where you get to climb all day if you want. You can try all different levels, same levels in different locations, watch people, take breaks, etc. There's even other fun things to do like walk on a rope (whatever that's called), and other fun balance things. I really liked this place! It's for all ages. Little kids were there and older adults were there. All ages were having a blast. I got REALLY tired. My arms and body couldn't handle more than 4 hours lol but I'm sure others can. I definitely recommend this place! My sister and I really enjoyed it. We're definitely coming back with other people to share the experience!",
#   'date': '7/23/2017'},
#  {'review_id': 'ZWF8Fx9mevHX0m1K8raGpg',
#   'user_id': 'WKIW7tWyMq7_XN0V2ouo0A',
#   'user_name': 'Rebecca W.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 3,
#   'funny': 1,
#   'cool': 2,
#   'text': "This was such a cool place and a great place to learn how to climb for beginners, like myself! If you live in the Bay Area and haven't been here yet, shame on you! These indoor rock climbing gyms are such a treat to have. They are yet to come in Baton Rouge, LA so I was excited to visit this one. It was our first time there and I have never done rock climbing without the use of an auto-belay device. Unfortunately, since we did not receive any prior training we could not clime the higher walls here without doing a formal belay session. So, they gave us the option of bouldering, which was also really neat to do! My 7-year old daughter is obsessed with rock climbing and I enjoy it, too, but wish I had more upper body strength. It is hard! Bouldering was fun and has no belay, so you climb and either have to jump from the top or climb back down. I was exhausted and super sore afterwards. My daughter was into trying all the difficulty levels and enjoyed jumping off of the wall. For the record, I was super sore for a couple days, but totally worth it. Now, I am looking forward to the one opening up here in Baton Rouge! #climb",
#   'date': '9/23/2016'},
#  {'review_id': 'tCxxAzvU4vgmjiOB8ZAvng',
#   'user_id': 'OIZkIV3wKzYUt3qCZiedyw',
#   'user_name': 'Kristina L.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'A fun spot. Great for a day adventure. I often climb with my brother for two hours, get some food and climb a bit more. There are saunas, steam rooms and showers in the restroom area. Classes for climbing as well as various other activities. The staff is helpful and generous. \xa0Sometimes there is no one behind the desk though. Looks like they are busy. Worth checking out. Especially for hosting birthday parties.',
#   'date': '4/22/2016'},
#  {'review_id': 'ZyGTN8M5b_j9bT3h0MgyIA',
#   'user_id': 'W70ZbP1PYFo2pNkGJaONPQ',
#   'user_name': 'Ruth R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "This place is great! My husband and I booked and paid for an intro class and weren't able to make it but they let us reschedule to another date even after we didn't notify them ahead of time. That's beyond customer service-- that's just very accommodating. Lots of choices for rock climbing. They also have spin, yoga, and crossfit along with standard gym equipment (treadmills, weights, etc.). It can get very busy and isn't the newest/cleanest gym but the vibe is very inviting and encouraging. It can be pricey so either get a membership or go for a treat.",
#   'date': '4/16/2017'},
#  {'review_id': '8ubT1q9VNX141gu5xxFROw',
#   'user_id': 'H5EY1CeIx4m_pNChKZkq7A',
#   'user_name': 'Kathy V.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 19,
#   'funny': 16,
#   'cool': 18,
#   'text': 'Who would of thought BOULDERING is a real work out? My first time experience was a fun aspect but also tough. A lot of upper body strength using your core and mind boggling trying to figure out which spot to use as leverage. Came here and made it a mother daughter day with the mini and had a fabulous time. Glad this gym actually had a lot of \xa0weight equipment, treadmills, ellipticals, and a swimming pool because I needed to get in some cardio before climbing. Diablo gym has friendly staff & a spotless gym. Will I be back? YES!!!',
#   'date': '6/14/2013'},
#  {'review_id': 'sDZHN35x-ONYLSoR9AHsAQ',
#   'user_id': 'klimqE5wcyla2-XFp0EZ5w',
#   'user_name': 'Ryan F.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "My favorite gym!! Great place to do whatever workout you like. I love the atmosphere and the staff is always helpful and accommodating. Also, I met my wife there! So it'll always hold a special place in my heart!",
#   'date': '10/11/2017'},
#  {'review_id': 'yQg1OlYGvWTSVTJViXcfdQ',
#   'user_id': 'NCAO2KuKuOeMUM7kvXl7Fw',
#   'user_name': 'Sasan S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Only been here a few times with friends who are members... Very dope place. On top of the rock walls and bouldering area there's weight equipment, locker rooms equipped with showers steam room & sauna, yoga classes offered, I think cross fit too? Not sure what the deal is with these guys and Diablo cross fit but I'd assume if you're a member of either you probably get some sort of deal if you want to use the other? Clean place, cool people, friendly employees. It is a little steep for a student like myself I think a monthly membership runs something around $67 but considering all the stuff you can use that's not bad at all.",
#   'date': '12/10/2016'},
#  {'review_id': 'UkH8AsDk9YYKKVKIiNjMeA',
#   'user_id': 'hrJJTeIsTGwbI6opklqxQA',
#   'user_name': 'Kelly B.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I went once and johnny helped me out at the front. I had never been before and he was helpful and set me up with a good pair of shoes! It was great to have such a friendly guy working there. The gym was pretty cool, too. I mostly hung in the freestyle area (I'm not sure what the actual name of the area is but it doesn't have rope) and that rock climbing is harder than it looks!!",
#   'date': '11/21/2016'},
#  {'review_id': 'uNvlTv_EbT19ypCp-tRP-w',
#   'user_id': 'syXbU628RijMfq41To7RzQ',
#   'user_name': 'Adele Y.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "My husband and I went here today with some coupons for a free full day. It's a pretty big gym with many walls to climb and countless routes. There's also bouldering as well as a fully equipped workout gym, though we did not use it. The staff members were all a delight and knew their stuff. It was easy to get belay certified but we still felt safe and well trained. My only negative is that it closes pretty early. Overall, we were both well challenged and both had a lot of fun!",
#   'date': '8/5/2017'},
#  {'review_id': 'm2d6Osr0bszJZ2y9p1jruw',
#   'user_id': '1JXiOwNGkJsPLz7eE1CKxw',
#   'user_name': 'Lillian T.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 3,
#   'useful': 5,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I came here a few months ago with my boyfriend. It was our first time at this rock gym. We bought tickets online for the beginners class + day pass package. It came out to be around $30 a person. The last time I had been rock climbing (not here) was about 3 years ago and I remember the class being very informative and slow paced...I mean you could really mess up in this sport so it should be. We started out with the class (this is what brought down the stars): A guy with a cap came over and gave us our harnesses, belay, and carabiner. He then proceeded to show us how to tie everything...super fast like we just needed a refresher. Uh, we are noobs, can you slow down? We were with another couple at the time who were first timers as well and we all had trouble keeping up. He acted very impatient every time we were slightly confused. After asking many questions and getting the same "you should already know this" attitude, we finally suited up and were ready to climb. The rest of the trip wasn\'t that bad. They had many levels from easy to extremely difficult climbs. We tried all the easy to medium ones with the latter being good challenges for us. They also had a tightrope for you to try if you were feeling adventurous, which we were. Although, there are other gyms that are much bigger in comparison, this one was a decent size and you could easily spent 3 hours here.All in all, if we were there to just climb without the lessons, I could go again. I have to just keep practicing in the air with how to tie the ropes so I don\'t forget and can pass the test. Not having to deal with the people who work there every time would be best. Otherwise, I\'d definitely pick somewhere else if you were just starting.',
#   'date': '10/21/2015'},
#  {'review_id': 'fy1Pm9VQBZJnGDJx2Sy-5w',
#   'user_id': 'Va-je-EVdeY7rkwOFYJM_A',
#   'user_name': 'Jennifer S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 1,
#   'cool': 0,
#   'text': 'I\'m in charge of organizing our boy scout troops climbing merit badge event at Diablo Rock Gym & yesterday was the second time we\'ve attended this location in 2 years. Theo, William & Stephan did an outstanding job! Their love of the sport combined with the understanding & patience as instructors, really fit the scouting spirit of "fun with a purpose". We even had a few scouts who were afraid of heights & unsure if they could complete the course but Stephan was at the top of the rock wall encouraging while Theo and William stood at the bottom ensuring them they were right there to make sure everything was safe & secure. Thanks to our 3 instructors; every scout finished the course with a smile, sense of accomplishment & earned merit badge!I\'d highly recommend every local boy scout troop come check out Diablo Rock Gym\'s Merit Badge Class. It\'s an amazing deal at $40 per scout for 4 hours of learning, practicing & instructors dedicated to making sure each boy succeeds! It\'s truly an amazing deal & good time had by all.',
#   'date': '4/17/2016'},
#  {'review_id': 'Gwi-oXNIzqCa_bdp-F5Hmg',
#   'user_id': 'Ls8HPGKQGgIuEhaZKCKJLA',
#   'user_name': 'Jordan B.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 1,
#   'cool': 1,
#   'text': "It's the spot! Great environment; friendly people and staff. For $70 a month full workout gym, rock climbing, and crossfit classes! Best deal in town. The have both top rope and bouldering as well. Awesome spot for the adventurous!",
#   'date': '10/9/2015'},
#  {'review_id': 'J2ghsHCadrgm0CFCqVD61Q',
#   'user_id': 'tPMXArPWmfUtpsw_uQSYsg',
#   'user_name': 'Andy A.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': 'I love this place. Had been climbing here since late 2008 and had to cancel and rejoin a couple of times. I will say the 2017 prices seem a little out of control. I was in last week with a friend and noticed the prices that had been posted and the day rate is going from $20 to $25. Seriously a 25% increase in a daily rate, which does not include shoes or any gear. Thankfully I have my own gear otherwise I would be about $30 bucks just to climb for a little while.. Also, the monthly rate seems to go up 2 bucks a year, so I guess that is to be expected. I have always had my gripes with gyms and their initiation fees. Really a $100 for someone to plug in some data entry? Outside of my nickel and diming complaints the gym is very well equipped. More than adequate climbing areas and a solid workout room. Lots of classes and workout styles that are accommodated. In the last almost decade here I have met so many good friends and made so many memories. The service is amazing with super friendly and helpful staff and solid amenities I will keep it a 4 and ding it the one star for the shortsighted pricing policy though.Update:Hans from the gym let me know that the day rate had not changed in like 5 years and that the initiation fee is waived during the month of January.',
#   'date': '1/5/2017'},
#  {'review_id': 'GFOBYy-EdaxGiWDAUYrLKw',
#   'user_id': '6k_GT_Ssn8llBzN3kQaQcQ',
#   'user_name': 'Bryten P.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 4,
#   'funny': 0,
#   'cool': 1,
#   'text': "I had only been to DRG one other time years ago. My friend that I went with and I are both very new to climbing. Even though we didn't come on a new class night, Kyle still took the time to show us how to belay and tie the rope correctly. The staff were all very helpful, especially Kyle going out of his way to make sure we were very competent and safe. I have already gone back again since the first time we went last week and I plan on going more because it was such a great experience.",
#   'date': '7/31/2015'},
#  {'review_id': 'p_PSjUT_r6vpMx0dOGZL9Q',
#   'user_id': 'PPiYZDUh_gFDIuq9b3r1cQ',
#   'user_name': 'Krissy L.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 7,
#   'funny': 6,
#   'cool': 7,
#   'text': "Not bad! Diablo Rock gym is definitely baby-sized compared to its other sister sites, but it definitely does NOT lack dynamics. They still provide great routes that is challenging for all levels! It can get a bit crowded though, especially in the evenings and weekends, but it's not that bad. I also love the staff members here, they're all very chill and very helpful. Feels a bit on the slow side, but for some reason, it doesn't bother me. Probably because the music is so hypnotizing and the general atmosphere is super relaxed. The bathrooms here are very nice and clean and VERY EMPTY. I'm pretty sure I could go butt naked in here for a good hour and nobody would know. They also provide nice smelling shampoo, conditioner and body wash as well as blow dryers and brushes (pretty dirty though). I think they also provide towels, but I always bring my own anyway so who knows.",
#   'date': '6/25/2015'},
#  {'review_id': 'm0jgFdp5CTyH9KpJ7t0b_Q',
#   'user_id': '9VIqYPRgaNUhcrYE4q39lg',
#   'user_name': 'Michael W.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "The positivesBig place with lots of walls to climb and a decent bouldering area.Amenities include steam room, hot tub, and towel service.Awesome classes include yoga, crossfit, stretching, and much more...They hold holiday parties and competitions regularly for members.Membership is fair at $72 a monthThe staff is very friendlyThe negatives Parking can be torturous during peak timesthey do a lot of parties and so kids can get in your way while you're climbing (though not a huge problem)The place is pretty popular and it can be crowded at time, but really only too crowded during peak hours.Occasionally I will come in and they will be resetting a large portion of the walls which gets in the way of my planned routine. This can be very frustrating and I wish they'd do this during their off hours.If it wasn't for the large amounts of kids running around at times, and the resetting of the gym during climbing hours I would give this place 5 stars.",
#   'date': '9/12/2015'},
#  {'review_id': 'tRpXSQJLFSDEiy6mEiTA-g',
#   'user_id': 'RlXfOTtpgTfcisRmukrGbw',
#   'user_name': 'Jenn C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 3,
#   'useful': 1,
#   'funny': 1,
#   'cool': 1,
#   'text': "Just had my first visit to the Diablo gym today and I had fun - it was nice that it wasn't crazy crowded at 10am. \xa0The main down-side is that the walls are only about 30' high. \xa0I think that the routesetters make up for that by doing more unique things for shorter routes with the starts and mix it up - a 10c/d was a lot more pumpy than I expected. \xa0 I found 11a and 11b routes to be more challenging which makes me think that the route setters partly rate based on endurance (not so much an issue with shorter walls) so there are more technical moves required on some of the routes, and a lot more different grades of overhangs at this gym.I just wish they had more lap swimming hours for members at nearby SwimTech - I would have stayed all afternoon! \xa0Looking forward to climbing here again.",
#   'date': '10/26/2013'},
#  {'review_id': 'Wm9vil-oqYx-2_LIuY4_mQ',
#   'user_id': '6mSczadyhSs6d6V2AS_x7g',
#   'user_name': 'Jon S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "I've been a Touchstone member for a bit now, but most of my time is spent at GWPC or Ironworks with the occasional jaunt over to Mission Cliffs or Dogpatch. I checked out Diablo for the first time and I was pleasantly surprised. Definitely a fan!From the outside, I was skeptical. The building didn't look very big, and while the walls aren't as tall as some of the other gyms, the number of routes for both bouldering and top-roping are actually pretty substantial. The gym also packs in a decent weight room/cardio equipment, a pool (!!), a dry and a wet sauna, plus exercise classes + a Crossfit gym as well. This is definitely one of the more all-inclusive gyms of the Touchstone family. The staff members here are great too. I didn't get a sort of pretentious/arrogant vibe that I've felt at a couple of the other gyms. My guest had shoes but needed a harness. The woman at the front desk comped the harness which I definitely appreciated. His belay test went smoothly as well and she was great about giving him some pointers. Overall, a super positive experience. If I'm ever back in the area, I'll definitely be back.",
#   'date': '8/1/2015'},
#  {'review_id': 'G5gfgW5T_BsHAcD6O1Jd5w',
#   'user_id': '7edHxOKYn5UwGXafHGRlAw',
#   'user_name': 'Robert R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 5,
#   'funny': 2,
#   'cool': 4,
#   'text': 'I had been here a couple times for a tour but never got a chance to get my "rock" on. My lil ones were interested in trying the place out and we went in a couple of times. It costs $15.00 for an hour with one instructor. We went 2 separate times and the instructor had about 3 other kids along my lil ones.They harness the kiddos and belay them to their hearts content. The staff is great with kids and are literally encouraging them to go higher and higher. They make you fill out the waiver on 1st visit, but once you complete it; your already in the system.',
#   'date': '2/23/2013'},
#  {'review_id': 'GKBc6QDc44IgV-ixhSzGaw',
#   'user_id': '1rwLFIEzMDjXggQFwii7wQ',
#   'user_name': 'Annie M.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 2,
#   'funny': 0,
#   'cool': 1,
#   'text': "I would give this place 5 stars for the staff alone! \xa0But since I've climbed several other gyms - it gets only 4 just because they are not nearly as huge-a-mungeous as Planet Granite in Sunnyvale where I first learned to climb. \xa0But it's very close!!! \xa0I think PG is only bigger than DRG because they have a fully enclosed gym area including a spin class etc. \xa0DRG also has a complete gym, but it doesn't have a tread climber and some of the other crazy contraptions I've seen elsewhere. \xa0 They have weights, treadmills, versa climbers, row machines.... full locker rooms with saunas and showers.The bouldering area is challenging as it has both cave climbs and all sorts of pitch complete with a climb up cliff and jump off (6' off the floor). \xa0Great variations for V0 all the way up to V9's for the pro's that also come to climb here. \xa0Hans Florine runs this place so it always has something for the advanced climber :-) \xa0They have the DRG Challenge board that allows anyone to compete throughout the year.Rope climbs are outstanding. \xa0They change the routes up every 6 weeks or so and make sure that there is ongoing variation throughout the gym. \xa0Everything from 5.2 (for kids and birthday parties, speed climbs for teens, and beginners alike) all the way up to 5.13d.Bring your own belay device. \xa0You can buy a gri-gri at the front desk, but you can rent a harness with an ATC.It's in a great location within a stone's throw of REI, Any Mountain, Lazy Dog, Elephant Bar, Panera, Fuddruckers... etc. \xa0So after you work up an appetite - you can finish off your day any way you'd like. \xa0Parking is no problem and everyone in the gym is very friendly and helpful. \xa0We love DRG!",
#   'date': '2/22/2015'},
#  {'review_id': 'Lzl3Kydy82Irw4WPT5gNWw',
#   'user_id': '7TkojMG64NyzCcc1scJkfw',
#   'user_name': 'Ryan C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': 'A great gym with super helpful and friendly staff make this place the best. \xa0You get free guest passes each month, they do not roll over, and on the last Friday of the month you get an extra pass. \xa0The routes change often enough to make it fresh. \xa0I will let you in on a little secret, come at 6am and there is only a handful of people in the weight room or on the walls. \xa0I am a huge fan!',
#   'date': '5/6/2013'},
#  {'review_id': 'r8WyU2WtNGw5CG0MwtvpCQ',
#   'user_id': 'zp-s59oGptp9uvzgjj5W9A',
#   'user_name': 'Gerald C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Love going here not only for climbing, but for lifting weights too! And if you like Crossfit, they have that as well!',
#   'date': '8/21/2016'},
#  {'review_id': 'Cfam1Bnb6noDQO9Mb9H8Vw',
#   'user_id': 'HFECrzYDpgbS5EmTBtj2zQ',
#   'user_name': 'Eric B.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 8,
#   'funny': 2,
#   'cool': 4,
#   'text': "Diablo Rock Gym is the far East Bay alternative to Ironworks. You have to really look to find it as it's tucked way back in this Industrial Park and right next to Aquatech Swim School. In fact, they connect inside and using the pool is possible after climbing up the wall of your personal and physical choice. Diablo Rock Gym is a nice facility, with manageable crowds and nice folks. And if rock climbing isn't your end all, there's also free weights, weight machines, and cardio equipment. The locker room is large clean with a saunas, and shower. There's also group classes in such things as indoor cycling, yoga, or the other classes that we offer. In other words, it's a gym option in its own right.",
#   'date': '6/12/2012'},
#  {'review_id': 'f1TXP8E2hAGMLyJ-fUEvIQ',
#   'user_id': 'Xm1OFHbp5XHV0ibzl4R-lQ',
#   'user_name': 'Jana R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 2,
#   'useful': 1,
#   'funny': 1,
#   'cool': 0,
#   'text': "I was in town for a business trip so I was by myself and had no belayer. \xa0There are no auto-belays and one of the tiniest bouldering areas that I've ever seen--plus the bouldering area was completely packed so there would have been a lot of waiting around for an open space. \xa0This place is probably 90% top-rope, which is great if you have a belayer. \xa0The price is $25 for a day pass and they refused to give me any sort of discount for only bouldering--it was obvious that I was by myself. \xa0If you have a partner, this is probably a fine gym but don't bother going if you're by yourself.",
#   'date': '2/22/2017'},
#  {'review_id': 'O7Fj2YdmlqvCsGY1gpmy4g',
#   'user_id': 'f0o054MKssU3HuaSagej7A',
#   'user_name': 'Kristine Y.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 1,
#   'useful': 11,
#   'funny': 5,
#   'cool': 0,
#   'text': 'My daughter was interested in rock climbing for her Bday, I was very excited to have found somewhere near that we can go to. I looked at your website & saw good reviews. We are all new to rock climbing and your facility, so we even went to check the gym before booking the party. And that\'s when I actually first noticed the poor customer service at your front desk. I had questions with the prices and how things worked if I wanted a party. Basically, left your gym that night saying to one of your front desk people: "Should I just look at your website?" Because honestly, he made me feel that he did not have time to answer my questions. A few days passed, since my daughter really wanted to rock climb for her Bday, I went ahead & called to book the party over the phone. I had a few questions first, coz again we are new to your facility & are not sure on how things work. Well, this is how it ended..I said: "You know what, I\'ll just book the party on line." Why? Because as I was trying to ask & talk to this someone on the phone, he was talking to someone else! I almost did not want to book the party there anymore at this point.Today...today was the day of the party. I already had an idea of what may go wrong, but I was hoping it would be different. Unfortunately, it was not. Our party was 4-6pm..I was told we are able to use the party room at this slot even though you don\'t offer it at this time on Sunday\'s. I came a little early @ 3:45pm to check in. We were checked in by JP or PJ. I asked if we are able to set up in the party room & he said there\'s a party that is still there & to check back in about 10 minutes. We check back at 3:55pm & asked someone else if the room was ready...JP or PJ annoyingly shouts "I already checked them in!" I had to step away because I did not want to loose it in front of my children and her guests. My husband finally spoke to an older gentleman & we were told that the room is being cleaned, but for the meantime the girls could start climbing. Katie was the girls instructor and if it weren\'t for her, my daughter\'s experience would\'ve been really awful. Katie was awesome! (She is the the reason for the 1 star) Thanks to Katie or else it would\'ve gotten really bad. The whole time that the girls were climbing, guess what happened to the party room? No one ever bothered to come up to me or my husband to follow up on it. We had our cooler, snacks & decorations for the room by the sofa waiting. I just told my husband to take everything to the car & forget it! If it weren\'t for one of your other staff over hearing me complain to my older sister about talking to the manager that someone finally talked to us. This was already probably 5:45pm! JP or PJ came out to apologize to my husband, but for what?! It was already done!!Improve your customer service at your front desk. Teach them just simple common courtesy. Teach them that they can\'t assume that not every person that walks in your gym is supposed to know what to do! I asked for climbing shoes for one of my daughter\'s guests & I get a snarky comment that her shoes is as good to use. I know that! She preferred climbing shoes! JP or PJ rolls his eyes and basically drops the shoes like he did not want to give it to us! Ask him if he heard anything from me?! I\'m a very patient person, but I could\'ve really lost it there at that point. I\'m an adult & your staff are all kids! They are hanging out there in front, flipping their hairs & acting like they can\'t be bothered! Please.. my daughter loved the experience climbing with Katie. I am really considering signing up so she is able to do more climbing. But if your front desk staff is not going to improve, I\'ll take my business somewhere else & soon other people would too. For the record, I am not complaining so that we can get free classes or a refund. Ask PJ or JP(whatever his name was!), because he did offer that to my husband. Unfortunately, this experience earned you this review.',
#   'date': '10/5/2015'},
#  {'review_id': 'IvbZ6HYuMg__5P1Pkz2xSg',
#   'user_id': 'XdYVYdHCsY26eMZbWko-sw',
#   'user_name': 'Rylah L.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 1,
#   'cool': 2,
#   'text': 'I love this place! Diablo Rock Gym is amazing. Such a positive and fun environment for learning to rock climb! The staff and other members are so nice and helpful.',
#   'date': '4/23/2014'},
#  {'review_id': '7z0K7pgK19032G7FEKqSVg',
#   'user_id': 'zpmePsBBwth_2G6jL1VTeg',
#   'user_name': 'El C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 1,
#   'useful': 5,
#   'funny': 2,
#   'cool': 0,
# ...
#   'date': '10/19/2013'},
#  {'review_id': 'xXFI8Wk6xEKUdbAeltazrQ',
#   'user_id': 'FpQEIFAoKRkh57F-ADQp2Q',
#   'user_name': 'Catherine D.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Great Staff ! Very clean facilities and stafff are cleaning and polishing daily, no odors. Pool is very clean without that strong chlorine odor. \xa0Lots of classes including Zumba, Yoga, Water Aerobics, Water Splash, Cycling. Great Rock Climbing training and practice.. Excellent Personal Trainers \xa0and Swim Instructors. \xa0Highly RecommendTo the Owners : \xa0PLEASE Offer a Daytime Water Aerobics class , lots of us from SSM want a class \xa0so much that my friends in Concord and Walnut Creek and Pleasant Hill drive all the way to Livermore three times a week for a daytime water aerobics class at another gym, you will definitely fill the classes :-))',
#   'date': '8/22/2011'},
#  {'review_id': 'jUY_rx-r4Ux3Mtm9hX8VtQ',
#   'user_id': 'gf4tyQgQOtVMkOdvveRHVA',
#   'user_name': 'Henry S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Came here a couple months ago to hang out with some friends who are recreational rock climbers. \xa0I had to the chance to check out what they all keep talking about. \xa0Although rocking climbing isn't something \xa0im into, this gym features a huge work out area with a bunch of cardio machines, spin classes and big ass rocks to climb on. \xa0Staff was friendly and the changing rooms were clean.",
#   'date': '6/6/2011'},
#  {'review_id': '3mG_uF-7omIkYzyHvzRajw',
#   'user_id': 'OaRk-RwFEzfOtc45ff0fGA',
#   'user_name': 'Jenn C.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Rates are comparable to Planet Granite (referring to the one in San Francisco), but I'd probably say the most notable difference was the fact that Diablo Rock Gym uses the older model of harnesses and ATC devices instead of the Grigri, so the belay test is slightly different. \xa0Aside from that, the ropes seemed a bit stiff and worn on the ends but the staff were nice (when you're finally able to flag one down).",
#   'date': '4/9/2011'},
#  {'review_id': '1wqMOBjEURypkZtNOqm8vA',
#   'user_id': 'OT3D55achPotu9QERZcCNQ',
#   'user_name': 'marcella r.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I come to concord the most out of all the gyms but it is still the nearest and dearest to my heart. generally good slab routes ftw! the staff is all really nice and am now buddybuddy with a few. and the absolute best thing about this plcace? THE MUTHAFIN STEAM ROOM! oh man, my love of steam rooms is ridiculous. there is also one of the trainers there, Rubin, who is very nice and open to talk to whenever he is there.',
#   'date': '5/23/2009'},
#  {'review_id': 'RMIYjbCAIuKv9mSzOf-ISQ',
#   'user_id': 'KoRmFHTVPjOlO_dG0WXnpw',
#   'user_name': 'Matt H.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 3,
#   'funny': 0,
#   'cool': 1,
#   'text': "Fantastic! This gym has more classes than any other gym I've been to: cycling, TRX, Crossfit, yoga, core, and others. In addition to being a great general gym, it also stands out as a wonderful climbing gym. The route setters do a great job putting up routes/problems for people of all levels. Also, there is access to an indoor pool. The front desk staff are friendly and helpful. The overall feel is laid-back. I don't feel judged here. I have nothing but positive things to say about this gym.",
#   'date': '1/5/2012'},
#  {'review_id': 'Nrx2o_C-U3WlOy94fryKDA',
#   'user_id': 'AZtDj1WfNkkb78uBYRtaoQ',
#   'user_name': 'Stefani P.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': 'Diablo Rock Gym is the place I call home for my fitness needs, so deep down I love it - but this is an unbiased view from a relatively new climber - I\'ve been a member of Touchstone for 3 months now. First off 90% of the time this place is pretty peaceful. There are a lot of route options for belay, lead and bouldering, with ranges in difficulty that will suit any level climber (5.2 is the lowest I\'ve seen). The walls are shorter than the other Touchstone locations, but personally I like that because I\'m still building muscle. The staff is great about regularly cycling the routes to keep things new and exciting. Great overhang on both the lead wall and the bouldering wall, even though I\'m still too novice to touch them. Overall it\'s a fantastic gym - very open and inviting. I\'ve never had a problem getting a weight/cardio machine even at peak hours of the day. Never have to wait for belay routes. Never have to wait for boulder routes. They offer classes every day (Yoga, Cycle, & Zumba) though I haven\'t checked any of them out yet (not big on classes). It\'s just a great place to get in, do your thing, shower, and go home. The staff are all very friendly and helpful. Bonus for me that it\'s 5 minutes from my house.Now the cons, because every place has them... Luckily there are only two, both of which I consider tolerable. The biggest "meh" I have with DRG is that it seems like they run a babysitting service from at least 4:45pm (when I usually arrive) until about 7-ish. During the week there\'s quite often a group of kids running around with one or two young guys monitoring them - MOST of the time. I\'ve honestly had kids from that group climb up bouldering routes that criss-cross with mine first being below me and then above me (they\'re so quick!) to the \xa0point where I have to pause my course because I don\'t want to have one of them fall/jump on me or vice versa. They often socialize at the bottom of belay climbs just swinging on the ropes (not climbing), or tear around the gym at high speeds. I understand it\'s the suburbs, but I\'m there to work out, not to dodge children. There should be a level of maturity in these kids, otherwise they shouldn\'t be in a gym in the first place.The only other issue I\'ve had is that the showers don\'t seem to get very hot. I don\'t need scalding, but something that is above lukewarm would be nice. I\'ve been in the shower with it on as hot as it will go and still had goosebumps, and that\'s no good when all I want to do is wash the sweat out of my hair - I should have enough heat for a 7 minute shower that won\'t leave me shivering.Other than those two small issues, Concord is great, and even if these situations remain the same I will continue to go there because the pros of diverse and mostly available climbs/machines, relative tranquility, and proximity to my house definitely outweigh the random unruly children and less than hot showers.',
#   'date': '5/26/2010'},
#  {'review_id': 'tgLaCHXg0-v2Yi2bDYX7Ig',
#   'user_id': 'GeDVfLDCXYdClMLSWBGs-A',
#   'user_name': 'Carol S.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I've been a member here for over a year now, and I love it. Friendly staff, good yoga classes and very social crowd, for the most part. I've been able to pick up random climbing buddies after hanging out in the bouldering pit a while, but on days when I don't want to talk to anyone and just want to climb, I can do that too. Towel service, steam room, sauna, pro shop (SNACKS!! need more calories to burn!), and plenty of folks around to help give tips and suggestions make this a good place to learn to climb. Seems like there's always a group of Boy Scouts, a birthday party, or multi-generational family group there in the afternoons and evenings, but the mornings are pretty quiet and calm if you prefer that. As of March 2011 they just got in new rental shoes, which is nice. Better to get your own if you want to stick to the walls on a regular basis, though. Oh yeah... REI is practically across the street (Willow Pass Road), so you can do that pretty easily. Check out their rope and bouldering competitions throughout the year, and get a membership so you can check out all the other Touchstone gyms. Totally worth it. I started out as a rookie last year, and between all the climbing and yoga I've done there, I feel fantastic.",
#   'date': '3/16/2011'},
#  {'review_id': 'rSB0QBn9t7Zd6TsbLLtpIA',
#   'user_id': 'g8oRkV4UoHA2hpl8eWxXPQ',
#   'user_name': 'Christine D.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 4,
#   'funny': 3,
#   'cool': 2,
#   'text': 'A couple of my friends and I decided to try this place out. \xa0Fortunately, we found this spot. \xa0Would definetly go again.',
#   'date': '5/25/2008'},
#  {'review_id': '1BvEkwBa0GDcAv4X4yNXHA',
#   'user_id': 'pme-jvQybv0I-zYjGCxROg',
#   'user_name': 'Cindy Lou K.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "3 and 1/2 really. \xa0But only because I go for the yoga. World Yoga in WC closed suddenly and left the yoga community orphaned. \xa0Sarah P. from Diablo Rock invited me to try 2 free classes. \xa0Since I'd only practiced @ WY, I'd say my bar is probably set a little high for my yoga experience. \xa0The class was great but I was distracted by the music from the spin class in the next room. \xa0I am not used to conversations outside the door. \xa0But the class was challenging and free. \xa0For future yoga classes, it $10 to drop in. \xa0A bargain considering the usual $15/$16 rate. \xa0Maybe I'll get used to the noise?",
#   'date': '6/29/2008'},
#  {'review_id': '1_CqMrp_aYpQnK23dXckgA',
#   'user_id': 'siaEE64_5sOtd_3OQpFirw',
#   'user_name': 'Audis V.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Great place to get a great workout. It is a gym, but unlike any other. The fact that you can come in, get your rock climbing shoes if you don't have any, and either boulder or rock climb \xa0all you want is something that is great about this gym. You can work on the machines (elliptical, treadmill, etc.) of course, but just the environment is nice. Small, isolated gym, but worth traveling to. I'm not a fan of gyms because of the many kinds of people that go there who are very vain. Here? You don't get that vibe. Everybody is doing their thing and not worried about what you do which is nice when you sometimes want to try something new without you having that feeling that others may be judging you.",
#   'date': '12/11/2009'},
#  {'review_id': '6t89eAXSfPAlPcRb3egsnQ',
#   'user_id': 'du1glKsorOEyfr3NCodcZw',
#   'user_name': 'Jaden V.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 1,
#   'useful': 4,
#   'funny': 2,
#   'cool': 0,
#   'text': 'Let me be clear about what I\'m writing about: the claim that they have a POOL... that you can swim in. \xa0I wanted to give them a try because they offered a pool.... well if you can call it a pool. \xa0No doubt the rock climbing part of the gym looks fantastic, but if you want to swim - you are better off in your bathtub. \xa0The locker rooms that have the steam / sauna / showers and lockers are NOT attached to the "pool". \xa0In order to get to the locker rooms where you can change before going to the "pool" you have to walk through the entirety of the gym - around the weights section, through some doors, around the "pool" - then into a hallway that has a men\'s restroom sign. \xa0At first I couldn\'t believe that this was the locker room for the pool. \xa0Upon entering it turns out I was half right. \xa0It was the place where the gym owners expect you to change and shower if you are using the pool, but it was NO locker room. \xa0The List: \xa0the lights half work and then turn off on you after 5 minutes (only way to get them to turn back on it to go back to the door and wave your hand at the sensor), even with the lights on the toilet had NO light, the VAST majority of the lockers are broken with no way to actually lock them, the few lockers that work are on the bottom and in the corner, the "shower" is a hole in the wall with no curtain (looked as though it had one of those shower heads that spray ice cold water at you with speeds that could pierce skin or that it would just trickle out), the whole hole smelt like mold and a homeless persons dirty socks. Now lets move onto the main event... the "pool". \xa0If you are a swimmer and by swimmer I mean someone who swims... not someone who swims a lap or two and then lallygags for one end to the other - this "pool" is NOT for You! \xa0It is perhaps the dingiest thing I have seen in a great while. \xa0The entire "pool" is 3 ft-ish deep. \xa0I\'m 6\'2" and when I swim I don\'t like my fingers hitting the bottom, and although I am flexible and can get pretty compact during a flip turn, the water level is such that it is not sufficient enough for me to do one. To sum up the whole experience including the entire look of the "pool" SAD SAD & SAD!! Probably the WORST pool I\'ve swam in since moving to CA. I\'m sorry I wasted the money on the month of unlimited swimming.',
#   'date': '2/1/2012'},
#  {'review_id': '-cDUwEm6UWgjhJI4ibfpyQ',
#   'user_id': 'BhLv1A3wCynI1i_fgJxDNA',
#   'user_name': 'Sam O.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 1,
#   'cool': 0,
#   'text': 'great crowd, great staff, great routes, and now a pool being put it too?? screw 24 hour fitness, this place is worth every penny, now if they only rented lofts next door so i didnt have to drive there every day my life would be perfect.',
#   'date': '8/27/2010'},
#  {'review_id': 'l3ew5U94ZRvtCmFUmeVG4w',
#   'user_id': 'NpGXAgdQfMBwg0ijaitq3A',
#   'user_name': 'Andy Y.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 2,
#   'funny': 0,
#   'cool': 1,
#   'text': 'this is my local gym. \xa0i usually boulder. \xa0they have a full fitness center and decent locker rooms. \xa0the staff is friendly and down to earth. \xa0and the other members there are cool too. \xa0i always end up talking to people while i climb. \xa0to help them with a problem or be helped. \xa0i became a member back in june of 07 and i have learned a lot from this place considering how small their bouldering area is. \xa0its not as large as ironworks in berkeley but it gets the job done and it doesnt get as busy as them. \xa0and the physical trainer there is a former nfl player named ruben. \xa0everything you need to do to train is here except for a pool and track but whatever. \xa0i love this place. \xa0not only do you get a membership to other good gyms, you also get a free subscription to Rock and Ice, a magazine that goes for $5.99 an issue.',
#   'date': '3/12/2008'},
#  {'review_id': 'g9FabY6daY8yk3vBurO72g',
#   'user_id': 'ZeIWoBsxfw8AW_Uomp5C0Q',
#   'user_name': 'Joel W.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 4,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "totally rockin'! \xa0smaller than berkeley ironworks and sf mission cliffs, but plenty of quality routes (same route setters) and far fewer people. \xa0and it costs less to be a member here. \xa0nice lead routes on the prow, which is fantastically overhung. \xa0i dig it.",
#   'date': '2/2/2006'},
#  {'review_id': 'lUSAupdaVSoEaUO63RdPZA',
#   'user_id': '0AWvfDGseHq54UlFCLAh8g',
#   'user_name': 'Peter R.',
#   'business_id': 'ImFFWa6UEu_fhfODG1yBiQ',
#   'stars': 5,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Awesome place. The place is really clean and organized. I went their with my youth group and everyone loved it. The people are nice and the price isn't bad. You get the most bang for the buck and I can guarantee and awesome time. The place is filled with options and it's an adventure.",
#   'date': '3/11/2009'})
